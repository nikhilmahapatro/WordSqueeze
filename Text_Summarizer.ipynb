# %% [markdown]
# # TEXT SUMMARIZER

# %%
Mutants = '''They called them mutants long before anyone agreed on a name. Magneto, Erik Lehnsherr, once said we are not the problem, we are the solution. But even he couldn't predict the 1973 incident at Lab-9, when a field surge flipped three labs and a meeting room into static soup. The staff logged it as 1973-11-06, 03:14 UTC. Victims four, two recovered. Sample IDs X-002, X23-A.

Jean Grey woke up with the taste of ozone and a headache that felt like someone had rearranged her skull. Not again, she whispered to herself. Telepathy, telekinesis, and the occasional reality hiccup were bad enough, but with sleep-deprived mood swings the odds of catastrophe rose sharply. Project Phoenix was mentioned in the files, always followed by emergency protocols in red ink.

Historical records show three power states: latent powers stayed hidden until some unknown trigger forced them out, active powers worked predictably like clockwork, and volatile powers refused any pattern at all, requiring strict containment. Lead-lined chambers, industrial foam, and total silence were common safety measures. The worst mistake was introducing water near an electrical mutant, and that rule was broken too many times.

Reed once claimed that the lattice could hold at negative one hundred twenty degrees Celsius if the feedline remained untouched. Hank never believed him, saying any sentence that started with if and ended with should was an invitation for disaster. In practice, they both knew the truth — nothing ever held for long.

There were always hyphenated words scribbled in the margins of reports, mother-in-law jokes that made no sense, X-men written in block capitals, numbers like 3.14 and 1e6 hidden in the data, random email addresses like professor.x@academy.org, and links to half-broken archives. Ellipses marked sudden stops, parentheses spiraled into nested loops, and no one could tell where one thought ended and the next began.

The last surviving entry from the Mutant Archive ended with a warning. Stay alive. Stay hidden. Or stay together. The rest of the world will not care which choice you make.

In 1986, the island of Genosha claimed it had no mutants. Satellite scans proved otherwise. Thermal anomalies marked twenty-three underground chambers, each averaging four meters below surface. Reports found on an encrypted drive spoke of collars tagged MK-IV, restricting cortical spikes to under 0.7 millivolts. The logs never named the captives, only numbers: 402, 718, 719B.

Storm hated confined air. The metal corridors of the submersible pressed on her senses like a steel coffin. Pressure readings rose with each dive, and her weather instincts fought the silence. The Atlantic above was calm, yet her bones ached as if a storm loomed just out of sight. Scott told her it was in her head. She didn’t believe him.

In training simulations, probability curves rarely matched reality. A model might predict an 85% chance of target neutralization, yet a coin dropped in the wrong moment could throw the result to zero. Logan treated probabilities as polite lies — useful only until the fight started. His claws made better arguments than any statistical forecast.

They never figured out why the Westchester alarm tripped at exactly 02:13 every third Thursday. Maintenance replaced wiring, swapped the backup generator, even gutted the entire subpanel. The alarm kept ringing, always the same timestamp, always cutting off after 41 seconds. Xavier wrote in his log that some things are not for fixing.

Cerebro’s records showed language anomalies among young mutants. One could speak twelve dialects after two hours of exposure, another could only communicate in palindromes. Written reports contained oddities like “madam I’m adam” repeated fifty-three times in a row, with no apparent meaning. Linguists left confused, telepaths left silent.

In 1999, a blackout across Eastern Europe lasted seventeen minutes. Satellite logs noted no solar flare, no geomagnetic spike, no explainable cause. Files later surfaced referencing “Subject Theta-7,” a mutant able to bend electromagnetic fields with nothing more than concentration. Witness accounts conflicted — some claimed to see a boy in the rubble, others swore no one was there at all. Energy signatures burned into the data like scars, still unexplained two decades later.

Jubilee once described mutant life as “walking into every room carrying fireworks no one asked for.” Her files included timestamps, discharge levels, and even stress ratings before each flare. Yet the most important detail was never technical — it was that her sparks made children laugh in shelters where hope was short supply. Analysts flagged the entry as “non-essential,” but it stayed in the record anyway.

Warpath wrote long, unfiltered reports filled with metaphors instead of measurements. He compared training halls to “caves echoing with steel,” and tactical drills to “storms waiting for permission to break.” His language baffled technicians but resonated with other mutants, who said they understood him more than any dry percentage or curve. Sometimes, his words revealed more truth than a hundred charts.

By 2005, geneticists tracked more than three hundred known mutations worldwide. They mapped alleles, cross-referenced genomes, and still ended with a margin of error wider than comfort allowed. A note buried in the data read: Evolution is not an equation, it’s a tide. You can measure waves but never predict when the ocean will rise.

Magneto’s prison cell was technically a floating room, suspended by non-ferrous cables over a saltwater pit. Every bolt and weld was ceramic. Guards rotated every ninety minutes to avoid familiarity, each carrying no metal larger than a paperclip. The design was flawless until someone smuggled in a simple belt buckle.

Some powers aged with their hosts. Pyro’s flames lost brightness after age fifty, while Colossus’s steel skin took longer to manifest each morning. Beast kept records of these declines, noting cellular efficiency drops in percentage points: 0.9, 1.3, 1.8. He called it entropy in slow motion.

Not all mutants fought. Some built. Forge once designed a drone the size of a fingernail that could map a city block in thirty seconds. It flew once, mapped perfectly, then exploded in midair. The debris weighed less than a feather. No one could replicate it.

Records of mutant births show spikes after high-energy events: solar flares, nuclear tests, and the unexplained blackout of ’94. Analysts plotted them on a timeline and found fractal-like patterns, repeating across decades. The same gap lengths, the same sudden rises. A cycle hiding in plain sight.

The last known sighting of Mystique was not on any battlefield but at a small train station in rural France. CCTV caught her walking past the ticket booth, face unshifted, carrying a book with no title on the cover. She boarded the train, sat by the window, and vanished when it emerged from the next tunnel.

Mutants aren’t just powerful — they’re proof that humanity can grow beyond its limits. They don’t rely on gadgets or alien bloodlines. Their abilities are part of who they are, stitched into their DNA, and that makes their heroism feel more personal. When a mutant saves a city, it’s not a mask or a machine doing the work. It’s them, body and soul.

People admire mutants because they were born carrying a weight most couldn’t handle. There’s no “before” for them — no moment where they were ordinary. They grew up different, learned to control dangerous gifts, and still chose to help a world that didn’t always help them. That resilience earns respect.

Everyday citizens can see themselves in mutants more easily than in other heroes. You can’t train to be from another planet or buy your way into super strength, but the idea that evolution could give anyone the potential to do great things is inspiring. Mutants make people believe that heroism is not just an accident — it can be destiny.

When a mutant steps in to stop a disaster, the crowd knows it’s more than just power on display. It’s living proof that humanity’s future might not be something to fear. It might be something to look forward to.

Mutants are born different. They don’t choose their powers, and they don’t wait for an accident or a cosmic event to awaken them. Their abilities manifest naturally, often in childhood, and that alone terrifies people. A hero in armor is a man in a machine. A mutant is something else entirely — living proof that nature can rewrite the rules at will.

For most citizens, it’s easier to trust heroes whose powers have an explanation. A soldier in a suit, a scientist bitten by something strange, an alien from another planet — those stories have beginnings and boundaries. Mutants have neither. Their origins are tangled in biology, genetics, and whispers of evolution, which means anyone, anywhere, could be one without knowing it yet. That uncertainty breeds fear.

Fear turns into prejudice fast. Newspapers talk about mutants as a “problem,” not as individuals. Politicians campaign on the promise of registration. Neighbors glance too long at a kid who runs faster than he should. When a mutant saves a city, the headlines still focus on the destruction caused during the rescue. If a non-mutant does the same, they get parades.

Superheroes are celebrated because they are seen as exceptional individuals — rare, special, chosen. Mutants are hated because they represent a future people can’t control. It’s not that the world doesn’t need them. It’s that the world fears it might become them.

Mutants sit in a strange place in the public mind. To some, they’re heroes — proof that evolution can push humanity forward. To others, they’re walking reminders that the world is changing in ways no one can control. Every time a mutant saves lives, the headlines split: one side celebrates, the other asks if their powers make them too dangerous to be trusted.

The admiration is easy to understand. Many mutants spend their entire lives training to keep their abilities in check, choosing to risk themselves to protect strangers. They face the same threats as any other superhero, but often without the public’s full support. That persistence is hard not to respect.

The fear comes from the unknown. A masked vigilante can hang up the suit. An alien can fly home. But mutants can’t stop being what they are, and no one can predict what abilities the next generation will have. For some, that’s exciting — a glimpse into the future of humankind. For others, it’s terrifying — a sign that humanity might become something unrecognizable.

And so, mutants live in this constant push and pull between acceptance and suspicion. Loved in some cities, feared in others, and always aware that a single bad moment could tip the balance.

Mutants didn’t ask to be born different. But the world treats them like it’s a choice. A hero in a cape gets a parade. A mutant in the same fight gets a police escort… to a containment cell.

It’s not about what they’ve done. It’s about what they could do. People fear that power they can’t switch off, can’t hand over, can’t control. Every mutant is a walking question mark, and humans hate unanswered questions.

The irony? Most mutants want the same thing as everyone else — a life. Friends. Peace. Safety. But the second their genes reveal something extraordinary, that dream burns up in suspicion.

For every cheer, there’s a jeer. For every handshake, there’s a locked door. Mutants fight for the people, but the people can’t decide if they’re saviors or the first wave of something worse.'''

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation

# %%
Mutants
# Out:
# "They called them mutants long before anyone agreed on a name. Magneto, Erik Lehnsherr, once said we are not the problem, we are the solution. But even he couldn't predict the 1973 incident at Lab-9, when a field surge flipped three labs and a meeting room into static soup. The staff logged it as 1973-11-06, 03:14 UTC. Victims four, two recovered. Sample IDs X-002, X23-A.\n\nJean Grey woke up with the taste of ozone and a headache that felt like someone had rearranged her skull. Not again, she whispered to herself. Telepathy, telekinesis, and the occasional reality hiccup were bad enough, but with sleep-deprived mood swings the odds of catastrophe rose sharply. Project Phoenix was mentioned in the files, always followed by emergency protocols in red ink.\n\nHistorical records show three power states: latent powers stayed hidden until some unknown trigger forced them out, active powers worked predictably like clockwork, and volatile powers refused any pattern at all, requiring strict containment. Lead-lined chambers, industrial foam, and total silence were common safety measures. The worst mistake was introducing water near an electrical mutant, and that rule was broken too many times.\n\nReed once claimed that the lattice could hold at negative one hundred twenty degrees Celsius if the feedline remained untouched. Hank never believed him, saying any sentence that started with if and ended with should was an invitation for disaster. In practice, they both knew the truth — nothing ever held for long.\n\nThere were always hyphenated words scribbled in the margins of reports, mother-in-law jokes that made no sense, X-men written in block capitals, numbers like 3.14 and 1e6 hidden in the data, random email addresses like professor.x@academy.org, and links to half-broken archives. Ellipses marked sudden stops, parentheses spiraled into nested loops, and no one could tell where one thought ended and the next began.\n\nThe last surviving entry from the Mutant Archive ended with a warning. Stay alive. Stay hidden. Or stay together. The rest of the world will not care which choice you make.\n\nIn 1986, the island of Genosha claimed it had no mutants. Satellite scans proved otherwise. Thermal anomalies marked twenty-three underground chambers, each averaging four meters below surface. Reports found on an encrypted drive spoke of collars tagged MK-IV, restricting cortical spikes to under 0.7 millivolts. The logs never named the captives, only numbers: 402, 718, 719B.\n\nStorm hated confined air. The metal corridors of the submersible pressed on her senses like a steel coffin. Pressure readings rose with each dive, and her weather instincts fought the silence. The Atlantic above was calm, yet her bones ached as if a storm loomed just out of sight. Scott told her it was in her head. She didn’t believe him.\n\nIn training simulations, probability curves rarely matched reality. A model might predict an 85% chance of target neutralization, yet a coin dropped in the wrong moment could throw the result to zero. Logan treated probabilities as polite lies — useful only until the fight started. His claws made better arguments than any statistical forecast.\n\nThey never figured out why the Westchester alarm tripped at exactly 02:13 every third Thursday. Maintenance replaced wiring, swapped the backup generator, even gutted the entire subpanel. The alarm kept ringing, always the same timestamp, always cutting off after 41 seconds. Xavier wrote in his log that some things are not for fixing.\n\nCerebro’s records showed language anomalies among young mutants. One could speak twelve dialects after two hours of exposure, another could only communicate in palindromes. Written reports contained oddities like “madam I’m adam” repeated fifty-three times in a row, with no apparent meaning. Linguists left confused, telepaths left silent.\n\nIn 1999, a blackout across Eastern Europe lasted seventeen minutes. Satellite logs noted no solar flare, no geomagnetic  ...

# %%
stopwords = list(STOP_WORDS) 
stopwords
# Out:
# ['someone',
#  'two',
#  'made',
#  'she',
#  'unless',
#  '’ll',
#  'being',
#  'eleven',
#  'but',
#  'latter',
#  'between',
#  'less',
#  'whole',
#  'through',
#  'across',
#  'very',
#  'below',
#  'or',
#  'no',
#  'you',
#  'your',
#  'could',
#  'indeed',
#  'latterly',
#  'wherein',
#  'hereafter',
#  'most',
#  'next',
#  'her',
#  'them',
#  'former',
#  'to',
#  'does',
#  'twenty',
#  're',
#  'perhaps',
#  'anyway',
#  'else',
#  "'ll",
#  'mine',
#  'back',
#  'us',
#  'up',
#  'side',
#  '’re',
#  'either',
#  'via',
#  'i',
#  'can',
#  '‘re',
#  'see',
#  'their',
#  'are',
#  'on',
#  'they',
#  'everyone',
#  'would',
#  'during',
#  'own',
#  'whoever',
#  'yourself',
#  'in',
#  'off',
#  'under',
#  'please',
#  "'ve",
#  'really',
#  'had',
#  'whenever',
#  'when',
#  'who',
#  'neither',
#  'whatever',
#  'around',
#  'am',
#  'the',
#  'name',
#  'doing',
#  'three',
#  'beforehand',
#  'this',
#  'enough',
#  'after',
#  'ever',
#  'which',
#  'until',
#  'hundred',
#  'almost',
#  'within',
#  'is',
#  '‘ve',
#  '’ve',
#  'upon',
#  'yourselves',
#  'elsewhere',
#  'such',
#  'him',
#  'take',
#  'itself',
#  "'m",
#  'hers',
#  'since',
#  'we',
#  'even',
#  'otherwise',
#  'quite',
#  'none',
#  'must',
#  'ourselves',
#  'hereby',
#  'anywhere',
#  'me',
#  'throughout',
#  'thereupon',
#  'keep',
#  'hence',
#  'here',
#  'twelve',
#  'themselves',
#  'sometime',
#  'nine',
#  'somehow',
#  'serious',
#  'among',
#  'wherever',
#  'will',
#  'these',
#  'ten',
#  'himself',
#  'while',
#  'beside',
#  'formerly',
#  'and',
#  'about',
#  'meanwhile',
#  'has',
#  'get',
#  'so',
#  'may',
#  'third',
#  'amount',
#  'beyond',
#  'much',
#  'anyhow',
#  'say',
#  'all',
#  'something',
#  'that',
#  'towards',
#  'used',
#  'became',
#  'namely',
#  'whence',
#  'whither',
#  'thereafter',
#  'seemed',
#  'done',
#  '’m',
#  'nobody',
#  'others',
#  'along',
#  'therefore',
#  'ca',
#  'due',
#  'every',
#  'becoming',
#  'various',
#  'regarding',
#  'whereby',
#  'further',
#  'his',
#  'per',
#  'mostly',
#  'top',
#  'what',
#  'another',
#  'have',
#  'why',
#  'only',
#  'go',
#  'whereas',
#  'call',
#  'five',
#  'part',
#  'put',
#  'show',
#  'against',
#  'from',
#  'give',
#  'there',
#  'bottom',
#  'empty',
#  'again',
#  'therein',
#  'except',
#  'still',
#  'using',
#  'first',
#  'toward',
#  'a',
#  'besides',
#  'into',
#  'seem',
#  'somewhere',
#  'well',
#  'without',
#  'herein',
#  'of',
#  'though',
#  'behind',
#  'sometimes',
#  'never',
#  'forty',
#  'should',
#  'my',
#  'as',
#  'make',
#  'before',
#  'our',
#  'not',
#  'move',
#  'with',
#  'myself',
#  'seeming',
#  'might',
#  'yours',
#  'onto',
#  'n’t',
#  'several',
#  'those',
#  "'re",
#  'fifty',
#  'thus',
#  '‘d',
#  'because',
#  'front',
#  'nowhere',
#  'often',
#  'thereby',
#  'six',
#  'was',
#  'same',
#  'four',
#  'were',
#  'too',
#  '‘s',
#  'anything',
#  'least',
#  'any',
#  'now',
#  'did',
#  'whereafter',
#  'if',
#  'whereupon',
#  'out',
#  'more',
#  '‘m',
#  'one',
#  'other',
#  'once',
#  'down',
#  'been',
#  'for',
#  'where',
#  'by',
#  'thru',
#  'together',
#  'whose',
#  'at',
#  'above',
#  'thence',
#  'already',
#  'full',
#  'seems',
#  'also',
#  'each',
#  'afterwards',
#  'yet',
#  'be',
#  'he',
#  'however',
#  'cannot',
#  '’d',
#  'everywhere',
#  'hereupon',
#  'always',
#  'both',
#  'alone',
#  'amongst',
#  'noone',
#  'become',
#  'last',
#  'whether',
#  'than',
#  'n‘t',
#  'becomes',
#  'everything',
#  'then',
#  'whom',
#  'ours',
#  'few',
#  'nothing',
#  'anyone',
#  '’s',
#  'rather',
#  "'d",
#  'its',
#  "n't",
#  'it',
#  'nor',
#  'how',
#  'an',
#  'although',
#  "'s",
#  'moreover',
#  'eight',
#  'many',
#  'over',
#  'do',
#  'sixty',
#  'nevertheless',
#  'just',
#  'fifteen',
#  'some',
#  'herself',
#  '‘ll']

# %%
len(stopwords)
# Out:
# 326

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp(Mutants)
doc
# Out:
# They called them mutants long before anyone agreed on a name. Magneto, Erik Lehnsherr, once said we are not the problem, we are the solution. But even he couldn't predict the 1973 incident at Lab-9, when a field surge flipped three labs and a meeting room into static soup. The staff logged it as 1973-11-06, 03:14 UTC. Victims four, two recovered. Sample IDs X-002, X23-A.
#
# Jean Grey woke up with the taste of ozone and a headache that felt like someone had rearranged her skull. Not again, she whispered to herself. Telepathy, telekinesis, and the occasional reality hiccup were bad enough, but with sleep-deprived mood swings the odds of catastrophe rose sharply. Project Phoenix was mentioned in the files, always followed by emergency protocols in red ink.
#
# Historical records show three power states: latent powers stayed hidden until some unknown trigger forced them out, active powers worked predictably like clockwork, and volatile powers refused any pattern at all, requiring strict containment. Lead-lined chambers, industrial foam, and total silence were common safety measures. The worst mistake was introducing water near an electrical mutant, and that rule was broken too many times.
#
# Reed once claimed that the lattice could hold at negative one hundred twenty degrees Celsius if the feedline remained untouched. Hank never believed him, saying any sentence that started with if and ended with should was an invitation for disaster. In practice, they both knew the truth — nothing ever held for long.
#
# There were always hyphenated words scribbled in the margins of reports, mother-in-law jokes that made no sense, X-men written in block capitals, numbers like 3.14 and 1e6 hidden in the data, random email addresses like professor.x@academy.org, and links to half-broken archives. Ellipses marked sudden stops, parentheses spiraled into nested loops, and no one could tell where one thought ended and the next began.
#
# The last surviving entry from the Mutant Archive ended with a warning. Stay alive. Stay hidden. Or stay together. The rest of the world will not care which choice you make.
#
# In 1986, the island of Genosha claimed it had no mutants. Satellite scans proved otherwise. Thermal anomalies marked twenty-three underground chambers, each averaging four meters below surface. Reports found on an encrypted drive spoke of collars tagged MK-IV, restricting cortical spikes to under 0.7 millivolts. The logs never named the captives, only numbers: 402, 718, 719B.
#
# Storm hated confined air. The metal corridors of the submersible pressed on her senses like a steel coffin. Pressure readings rose with each dive, and her weather instincts fought the silence. The Atlantic above was calm, yet her bones ached as if a storm loomed just out of sight. Scott told her it was in her head. She didn’t believe him.
#
# In training simulations, probability curves rarely matched reality. A model might predict an 85% chance of target neutralization, yet a coin dropped in the wrong moment could throw the result to zero. Logan treated probabilities as polite lies — useful only until the fight started. His claws made better arguments than any statistical forecast.
#
# They never figured out why the Westchester alarm tripped at exactly 02:13 every third Thursday. Maintenance replaced wiring, swapped the backup generator, even gutted the entire subpanel. The alarm kept ringing, always the same timestamp, always cutting off after 41 seconds. Xavier wrote in his log that some things are not for fixing.
#
# Cerebro’s records showed language anomalies among young mutants. One could speak twelve dialects after two hours of exposure, another could only communicate in palindromes. Written reports contained oddities like “madam I’m adam” repeated fifty-three times in a row, with no apparent meaning. Linguists left confused, telepaths left silent.
#
# In 1999, a blackout across Eastern Europe lasted seventeen minutes. Satellite logs noted no solar flare, no geomagnetic spike, no explainable cause. Files later surfaced referencing “Subject Theta-7,” a mutant able to bend electromagnetic fields with nothing more than concentration. Witness accounts conflicted — some claimed to see a boy in the rubble, others swore no one was there at all. Energy signatures burned into the data like scars, still unexplained two decades later.
#
# Jubilee once described mutant life as “walking into every room carrying fireworks no one asked for.” Her files included timestamps, discharge levels, and even stress ratings before each flare. Yet the most important detail was never technical — it was that her sparks made children laugh in shelters where hope was short supply. Analysts flagged the entry as “non-essential,” but it stayed in the record anyway.
#
# Warpath wrote long, unfiltered reports filled with metaphors instead of measurements. He compared training halls to “caves echoing with steel,” and tactical drills to “storms waiting for permission to break.” His language baffled technicians but resonated with other mutants, who said they understood him more than any dry percentage or curve. Sometimes, his words revealed more truth than a hundred charts.
#
# By 2005, geneticists tracked more than three hundred known mutations worldwide. They mapped alleles, cross-referenced genomes, and still ended with a margin of error wider than comfort allowed. A note buried in the data read: Evolution is not an equation, it’s a tide. You can measure waves but never predict when the ocean will rise.
#
# Magneto’s prison cell was technically a floating room, suspended by non-ferrous cables over a saltwater pit. Every bolt and weld was ceramic. Guards rotated every ninety minutes to avoid familiarity, each carrying no metal larger than a paperclip. The design was flawless until someone smuggled in a simple belt buckle.
#
# Some powers aged with their hosts. Pyro’s flames lost brightness after age fifty, while Colossus’s steel skin took longer to manifest each morning. Beast kept records of these declines, noting cellular efficiency drops in percentage points: 0.9, 1.3, 1.8. He called it entropy in slow motion.
#
# Not all mutants fought. Some built. Forge once designed a drone the size of a fingernail that could map a city block in thirty seconds. It flew once, mapped perfectly, then exploded in midair. The debris weighed less than a feather. No one could replicate it.
#
# Records of mutant births show spikes after high-energy events: solar flares, nuclear tests, and the unexplained blackout of ’94. Analysts plotted them on a timeline and found fractal-like patterns, repeating across decades. The same gap lengths, the same sudden rises. A cycle hiding in plain sight.
#
# The last known sighting of Mystique was not on any battlefield but at a small train station in rural France. CCTV caught her walking past the ticket booth, face unshifted, carrying a book with no title on the cover. She boarded the train, sat by the window, and vanished when it emerged from the next tunnel.
#
# Mutants aren’t just powerful — they’re proof that humanity can grow beyond its limits. They don’t rely on gadgets or alien bloodlines. Their abilities are part of who they are, stitched into their DNA, and that makes their heroism feel more personal. When a mutant saves a city, it’s not a mask or a machine doing the work. It’s them, body and soul.
#
# People admire mutants because they were born carrying a weight most couldn’t handle. There’s no “before” for them — no moment where they were ordinary. They grew up different, learned to control dangerous gifts, and still chose to help a world that didn’t always help them. That resilience earns respect.
#
# Everyday citizens can see themselves in mutants more easily than in other heroes. You can’t train to be from another planet or buy your way into super strength, but the idea that evolution could give anyone the potential to do great things is inspiring. Mutants make people believe that heroism is not just an accident — it can be destiny.
#
# When a mutant steps in to stop a disaster, the crowd knows it’s more than just power on display. It’s living proof that humanity’s future might not be something to fear. It might be something to look forward to.
#
# Mutants are born different. They don’t choose their powers, and they don’t wait for an accident or a cosmic event to awaken them. Their abilities manifest naturally, often in childhood, and that alone terrifies people. A hero in armor is a man in a machine. A mutant is something else entirely — living proof that nature can rewrite the rules at will.
#
# For most citizens, it’s easier to trust heroes whose powers have an explanation. A soldier in a suit, a scientist bitten by something strange, an alien from another planet — those stories have beginnings and boundaries. Mutants have neither. Their origins are tangled in biology, genetics, and whispers of evolution, which means anyone, anywhere, could be one without knowing it yet. That uncertainty breeds fear.
#
# Fear turns into prejudice fast. Newspapers talk about mutants as a “problem,” not as individuals. Politicians campaign on the promise of registration. Neighbors glance too long at a kid who runs faster than he should. When a mutant saves a city, the headlines still focus on the destruction caused during the rescue. If a non-mutant does the same, they get parades.
#
# Superheroes are celebrated because they are seen as exceptional individuals — rare, special, chosen. Mutants are hated because they represent a future people can’t control. It’s not that the world doesn’t need them. It’s that the world fears it might become them.
#
# Mutants sit in a strange place in the public mind. To some, they’re heroes — proof that evolution can push humanity forward. To others, they’re walking reminders that the world is changing in ways no one can control. Every time a mutant saves lives, the headlines split: one side celebrates, the other asks if their powers make them too dangerous to be trusted.
#
# The admiration is easy to understand. Many mutants spend their entire lives training to keep their abilities in check, choosing to risk themselves to protect strangers. They face the same threats as any other superhero, but often without the public’s full support. That persistence is hard not to respect.
#
# The fear comes from the unknown. A masked vigilante can hang up the suit. An alien can fly home. But mutants can’t stop being what they are, and no one can predict what abilities the next generation will have. For some, that’s exciting — a glimpse into the future of humankind. For others, it’s terrifying — a sign that humanity might become something unrecognizable.
#
# And so, mutants live in this constant push and pull between acceptance and suspicion. Loved in some cities, feared in others, and always aware that a single bad moment could tip the balance.
#
# Mutants didn’t ask to be born different. But the world treats them like it’s a choice. A hero in a cape gets a parade. A mutant in the same fight gets a police escort… to a containment cell.
#
# It’s not about what they’ve done. It’s about what they could do. People fear that power they can’t switch off, can’t hand over, can’t control. Every mutant is a walking question mark, and humans hate unanswered questions.
#
# The irony? Most mutants want the same thing as everyone else — a life. Friends. Peace. Safety. But the second their genes reveal something extraordinary, that dream burns up in suspicion.
#
# For every cheer, there’s a jeer. For every handshake, there’s a locked door. Mutants fight for the people, but the people can’t decide if they’re saviors or the first wave of something worse.

# %%
# lets get the tokens from text
tokens = [token.text for token in doc]
print(tokens)
# Out:
# ['They', 'called', 'them', 'mutants', 'long', 'before', 'anyone', 'agreed', 'on', 'a', 'name', '.', 'Magneto', ',', 'Erik', 'Lehnsherr', ',', 'once', 'said', 'we', 'are', 'not', 'the', 'problem', ',', 'we', 'are', 'the', 'solution', '.', 'But', 'even', 'he', 'could', "n't", 'predict', 'the', '1973', 'incident', 'at', 'Lab-9', ',', 'when', 'a', 'field', 'surge', 'flipped', 'three', 'labs', 'and', 'a', 'meeting', 'room', 'into', 'static', 'soup', '.', 'The', 'staff', 'logged', 'it', 'as', '1973', '-', '11', '-', '06', ',', '03:14', 'UTC', '.', 'Victims', 'four', ',', 'two', 'recovered', '.', 'Sample', 'IDs', 'X-002', ',', 'X23', '-', 'A.', '\n\n', 'Jean', 'Grey', 'woke', 'up', 'with', 'the', 'taste', 'of', 'ozone', 'and', 'a', 'headache', 'that', 'felt', 'like', 'someone', 'had', 'rearranged', 'her', 'skull', '.', 'Not', 'again', ',', 'she', 'whispered', 'to', 'herself', '.', 'Telepathy', ',', 'telekinesis', ',', 'and', 'the', 'occasional', 'reality', 'hiccup', 'were', 'bad', 'enough', ',', 'but', 'with', 'sleep', '-', 'deprived', 'mood', 'swings', 'the', 'odds', 'of', 'catastrophe', 'rose', 'sharply', '.', 'Project', 'Phoenix', 'was', 'mentioned', 'in', 'the', 'files', ',', 'always', 'followed', 'by', 'emergency', 'protocols', 'in', 'red', 'ink', '.', '\n\n', 'Historical', 'records', 'show', 'three', 'power', 'states', ':', 'latent', 'powers', 'stayed', 'hidden', 'until', 'some', 'unknown', 'trigger', 'forced', 'them', 'out', ',', 'active', 'powers', 'worked', 'predictably', 'like', 'clockwork', ',', 'and', 'volatile', 'powers', 'refused', 'any', 'pattern', 'at', 'all', ',', 'requiring', 'strict', 'containment', '.', 'Lead', '-', 'lined', 'chambers', ',', 'industrial', 'foam', ',', 'and', 'total', 'silence', 'were', 'common', 'safety', 'measures', '.', 'The', 'worst', 'mistake', 'was', 'introducing', 'water', 'near', 'an', 'electrical', 'mutant', ',', 'and', 'that', 'rule', 'was', 'broken', 'too', 'many', 'times', '.', '\n\n', 'Reed', 'once', 'claimed', 'that', 'the', 'lattice', 'could', 'hold', 'at', 'negative', 'one', 'hundred', 'twenty', 'degrees', 'Celsius', 'if', 'the', 'feedline', 'remained', 'untouched', '.', 'Hank', 'never', 'believed', 'him', ',', 'saying', 'any', 'sentence', 'that', 'started', 'with', 'if', 'and', 'ended', 'with', 'should', 'was', 'an', 'invitation', 'for', 'disaster', '.', 'In', 'practice', ',', 'they', 'both', 'knew', 'the', 'truth', '—', 'nothing', 'ever', 'held', 'for', 'long', '.', '\n\n', 'There', 'were', 'always', 'hyphenated', 'words', 'scribbled', 'in', 'the', 'margins', 'of', 'reports', ',', 'mother', '-', 'in', '-', 'law', 'jokes', 'that', 'made', 'no', 'sense', ',', 'X', '-', 'men', 'written', 'in', 'block', 'capitals', ',', 'numbers', 'like', '3.14', 'and', '1e6', 'hidden', 'in', 'the', 'data', ',', 'random', 'email', 'addresses', 'like', 'professor.x@academy.org', ',', 'and', 'links', 'to', 'half', '-', 'broken', 'archives', '.', 'Ellipses', 'marked', 'sudden', 'stops', ',', 'parentheses', 'spiraled', 'into', 'nested', 'loops', ',', 'and', 'no', 'one', 'could', 'tell', 'where', 'one', 'thought', 'ended', 'and', 'the', 'next', 'began', '.', '\n\n', 'The', 'last', 'surviving', 'entry', 'from', 'the', 'Mutant', 'Archive', 'ended', 'with', 'a', 'warning', '.', 'Stay', 'alive', '.', 'Stay', 'hidden', '.', 'Or', 'stay', 'together', '.', 'The', 'rest', 'of', 'the', 'world', 'will', 'not', 'care', 'which', 'choice', 'you', 'make', '.', '\n\n', 'In', '1986', ',', 'the', 'island', 'of', 'Genosha', 'claimed', 'it', 'had', 'no', 'mutants', '.', 'Satellite', 'scans', 'proved', 'otherwise', '.', 'Thermal', 'anomalies', 'marked', 'twenty', '-', 'three', 'underground', 'chambers', ',', 'each', 'averaging', 'four', 'meters', 'below', 'surface', '.', 'Reports', 'found', 'on', 'an', 'encrypted', 'drive', 'spoke', 'of', 'collars', 'tagged', 'MK', '-', 'IV', ',', 'restricting', 'cortical', 'spikes', 'to', 'under', '0.7', 'millivolts', '.', 'The', 'logs', 'never', 'named', 'the', 'captives', ',', 'only', 'num ...

# %%
len(tokens)
# Out:
# 2310

# %%
# We have to calculate the frequency of each word.

word_frequencies = {}

for word in doc:
    if word.text.lower() not in stopwords:
        if word.text.lower() not in punctuation:
            if word.text not in word_frequencies.keys():
                word_frequencies[word.text] = 1
            else:
                word_frequencies[word.text] += 1

word_frequencies
# Out:
# {'called': 2,
#  'mutants': 12,
#  'long': 4,
#  'agreed': 1,
#  'Magneto': 2,
#  'Erik': 1,
#  'Lehnsherr': 1,
#  'said': 2,
#  'problem': 2,
#  'solution': 1,
#  'predict': 4,
#  '1973': 2,
#  'incident': 1,
#  'Lab-9': 1,
#  'field': 1,
#  'surge': 1,
#  'flipped': 1,
#  'labs': 1,
#  'meeting': 1,
#  'room': 3,
#  'static': 1,
#  'soup': 1,
#  'staff': 1,
#  'logged': 1,
#  '11': 1,
#  '06': 1,
#  '03:14': 1,
#  'UTC': 1,
#  'Victims': 1,
#  'recovered': 1,
#  'Sample': 1,
#  'IDs': 1,
#  'X-002': 1,
#  'X23': 1,
#  'A.': 1,
#  '\n\n': 35,
#  'Jean': 1,
#  'Grey': 1,
#  'woke': 1,
#  'taste': 1,
#  'ozone': 1,
#  'headache': 1,
#  'felt': 1,
#  'like': 9,
#  'rearranged': 1,
#  'skull': 1,
#  'whispered': 1,
#  'Telepathy': 1,
#  'telekinesis': 1,
#  'occasional': 1,
#  'reality': 2,
#  'hiccup': 1,
#  'bad': 2,
#  'sleep': 1,
#  'deprived': 1,
#  'mood': 1,
#  'swings': 1,
#  'odds': 1,
#  'catastrophe': 1,
#  'rose': 2,
#  'sharply': 1,
#  'Project': 1,
#  'Phoenix': 1,
#  'mentioned': 1,
#  'files': 2,
#  'followed': 1,
#  'emergency': 1,
#  'protocols': 1,
#  'red': 1,
#  'ink': 1,
#  'Historical': 1,
#  'records': 3,
#  'power': 3,
#  'states': 1,
#  'latent': 1,
#  'powers': 7,
#  'stayed': 2,
#  'hidden': 3,
#  'unknown': 2,
#  'trigger': 1,
#  'forced': 1,
#  'active': 1,
#  'worked': 1,
#  'predictably': 1,
#  'clockwork': 1,
#  'volatile': 1,
#  'refused': 1,
#  'pattern': 1,
#  'requiring': 1,
#  'strict': 1,
#  'containment': 2,
#  'Lead': 1,
#  'lined': 1,
#  'chambers': 2,
#  'industrial': 1,
#  'foam': 1,
#  'total': 1,
#  'silence': 2,
#  'common': 1,
#  'safety': 1,
#  'measures': 1,
#  'worst': 1,
#  'mistake': 1,
#  'introducing': 1,
#  'water': 1,
#  'near': 1,
#  'electrical': 1,
#  'mutant': 12,
#  'rule': 1,
#  'broken': 2,
#  'times': 2,
#  'Reed': 1,
#  'claimed': 3,
#  'lattice': 1,
#  'hold': 1,
#  'negative': 1,
#  'degrees': 1,
#  'Celsius': 1,
#  'feedline': 1,
#  'remained': 1,
#  'untouched': 1,
#  'Hank': 1,
#  'believed': 1,
#  'saying': 1,
#  'sentence': 1,
#  'started': 2,
#  'ended': 4,
#  'invitation': 1,
#  'disaster': 2,
#  'practice': 1,
#  'knew': 1,
#  'truth': 2,
#  '—': 14,
#  'held': 1,
#  'hyphenated': 1,
#  'words': 2,
#  'scribbled': 1,
#  'margins': 1,
#  'reports': 3,
#  'mother': 1,
#  'law': 1,
#  'jokes': 1,
#  'sense': 1,
#  'X': 1,
#  'men': 1,
#  'written': 1,
#  'block': 2,
#  'capitals': 1,
#  'numbers': 2,
#  '3.14': 1,
#  '1e6': 1,
#  'data': 3,
#  'random': 1,
#  'email': 1,
#  'addresses': 1,
#  'professor.x@academy.org': 1,
#  'links': 1,
#  'half': 1,
#  'archives': 1,
#  'Ellipses': 1,
#  'marked': 2,
#  'sudden': 2,
#  'stops': 1,
#  'parentheses': 1,
#  'spiraled': 1,
#  'nested': 1,
#  'loops': 1,
#  'tell': 1,
#  'thought': 1,
#  'began': 1,
#  'surviving': 1,
#  'entry': 2,
#  'Mutant': 1,
#  'Archive': 1,
#  'warning': 1,
#  'Stay': 2,
#  'alive': 1,
#  'stay': 1,
#  'rest': 1,
#  'world': 6,
#  'care': 1,
#  'choice': 2,
#  '1986': 1,
#  'island': 1,
#  'Genosha': 1,
#  'Satellite': 2,
#  'scans': 1,
#  'proved': 1,
#  'Thermal': 1,
#  'anomalies': 2,
#  'underground': 1,
#  'averaging': 1,
#  'meters': 1,
#  'surface': 1,
#  'Reports': 1,
#  'found': 2,
#  'encrypted': 1,
#  'drive': 1,
#  'spoke': 1,
#  'collars': 1,
#  'tagged': 1,
#  'MK': 1,
#  'IV': 1,
#  'restricting': 1,
#  'cortical': 1,
#  'spikes': 2,
#  '0.7': 1,
#  'millivolts': 1,
#  'logs': 2,
#  'named': 1,
#  'captives': 1,
#  '402': 1,
#  '718': 1,
#  '719B.': 1,
#  'Storm': 1,
#  'hated': 2,
#  'confined': 1,
#  'air': 1,
#  'metal': 2,
#  'corridors': 1,
#  'submersible': 1,
#  'pressed': 1,
#  'senses': 1,
#  'steel': 3,
#  'coffin': 1,
#  'Pressure': 1,
#  'readings': 1,
#  'dive': 1,
#  'weather': 1,
#  'instincts': 1,
#  'fought': 2,
#  'Atlantic': 1,
#  'calm': 1,
#  'bones': 1,
#  'ached': 1,
#  'storm': 1,
#  'loomed': 1,
#  'sight': 2,
#  'Scott': 1,
#  'told': 1,
#  'head': 1,
#  'believe': 2,
#  'training': 3,
#  'simulations': 1,
#  'probability': 1,
#  'curves': 1,
#  'rarely': 1,
#  'matched': 1,
#  'model': 1,
#  '85': 1,
#  'chance': 1,
#  'target': 1,
#  'neutralization': 1,
#  'coin': 1,
#  'dropped': 1,
#  'wrong': 1,
#  'moment': 3,
#  'throw': 1,
#  'result': 1,
#  'zero': 1,
#  'Logan': 1,
#  'treated': 1,
#  'probabilities': 1,
#  'polite': 1,
#  'lies': 1,
#  'useful': 1,
#  'fight': 3,
#  'claws': 1,
#  'better': 1,
#  'arguments': 1,
#  'statistical': 1,
#  'forecast': 1,
#  'figured': 1,
#  'Westchester': 1,
#  'alarm': 2,
#  'tripped': 1,
#  'exactly': 1,
#  '02:13': 1,
#  'Thursday': 1,
#  'Maintenance': 1,
#  'replaced': 1,
#  'wiring': 1,
#  'swapped': 1,
#  'backup': 1,
#  'generator': 1,
#  'gutted': 1,
#  'entire': 2,
#  'subpanel': 1,
#  'kept': 2,
#  'ringing': 1,
#  'timestamp': 1,
#  'cutting': 1,
#  '41': 1,
#  'seconds': 2,
#  'Xavier': 1,
#  'wrote': 2,
#  'log': 1,
#  'things': 2,
#  'fixing': 1,
#  'Cerebro': 1,
#  'showed': 1,
#  'language': 2,
#  'young': 1,
#  'speak': 1,
#  'dialects': 1,
#  'hours': 1,
#  'exposure': 1,
#  'communicate': 1,
#  'palindromes': 1,
#  'Written': 1,
#  'contained': 1,
#  'oddities': 1,
#  '“': 8,
#  'madam': 1,
#  'adam': 1,
#  '”': 8,
#  'repeated': 1,
#  'row': 1,
#  'apparent': 1,
#  'meaning': 1,
#  'Linguists': 1,
#  'left': 2,
#  'confused': 1,
#  'telepaths': 1,
#  'silent': 1,
#  '1999': 1,
#  'blackout': 2,
#  'Eastern': 1,
#  'Europe': 1,
#  'lasted': 1,
#  'seventeen': 1,
#  'minutes': 2,
#  'noted': 1,
#  'solar': 2,
#  'flare': 2,
#  'geomagnetic': 1,
#  'spike': 1,
#  'explainable': 1,
#  'cause': 1,
#  'Files': 1,
#  'later': 2,
#  'surfaced': 1,
#  'referencing': 1,
#  'Subject': 1,
#  'Theta-7': 1,
#  'able': 1,
#  'bend': 1,
#  'electromagnetic': 1,
#  'fields': 1,
#  'concentration': 1,
#  'Witness': 1,
#  'accounts': 1,
#  'conflicted': 1,
#  'boy': 1,
#  'rubble': 1,
#  'swore': 1,
#  'Energy': 1,
#  'signatures': 1,
#  'burned': 1,
#  'scars': 1,
#  'unexplained': 2,
#  'decades': 2,
#  'Jubilee': 1,
#  'described': 1,
#  'life': 2,
#  'walking': 4,
#  'carrying': 4,
#  'fireworks': 1,
#  'asked': 1,
#  'included': 1,
#  'timestamps': 1,
#  'discharge': 1,
#  'levels': 1,
#  'stress': 1,
#  'ratings': 1,
#  'important': 1,
#  'detail': 1,
#  'technical': 1,
#  'sparks': 1,
#  'children': 1,
#  'laugh': 1,
#  'shelters': 1,
#  'hope': 1,
#  'short': 1,
#  'supply': 1,
#  'Analysts': 2,
#  'flagged': 1,
#  'non': 3,
#  'essential': 1,
#  'record': 1,
#  'Warpath': 1,
#  'unfiltered': 1,
#  'filled': 1,
#  'metaphors': 1,
#  'instead': 1,
#  'measurements': 1,
#  'compared': 1,
#  'halls': 1,
#  'caves': 1,
#  'echoing': 1,
#  'tactical': 1,
#  'drills': 1,
#  'storms': 1,
#  'waiting': 1,
#  'permission': 1,
#  'break': 1,
#  'baffled': 1,
#  'technicians': 1,
#  'resonated': 1,
#  'understood': 1,
#  'dry': 1,
#  'percentage': 2,
#  'curve': 1,
#  'revealed': 1,
#  'charts': 1,
#  '2005': 1,
#  'geneticists': 1,
#  'tracked': 1,
#  'known': 2,
#  'mutations': 1,
#  'worldwide': 1,
#  'mapped': 2,
#  'alleles': 1,
#  'cross': 1,
#  'referenced': 1,
#  'genomes': 1,
#  'margin': 1,
#  'error': 1,
#  'wider': 1,
#  'comfort': 1,
#  'allowed': 1,
#  'note': 1,
#  'buried': 1,
#  'read': 1,
#  'Evolution': 1,
#  'equation': 1,
#  'tide': 1,
#  'measure': 1,
#  'waves': 1,
#  'ocean': 1,
#  'rise': 1,
#  'prison': 1,
#  'cell': 2,
#  'technically': 1,
#  'floating': 1,
#  'suspended': 1,
#  'ferrous': 1,
#  'cables': 1,
#  'saltwater': 1,
#  'pit': 1,
#  'bolt': 1,
#  'weld': 1,
#  'ceramic': 1,
#  'Guards': 1,
#  'rotated': 1,
#  'ninety': 1,
#  'avoid': 1,
#  'familiarity': 1,
#  'larger': 1,
#  'paperclip': 1,
#  'design': 1,
#  'flawless': 1,
#  'smuggled': 1,
#  'simple': 1,
#  'belt': 1,
#  'buckle': 1,
#  'aged': 1,
#  'hosts': 1,
#  'Pyro': 1,
#  'flames': 1,
#  'lost': 1,
#  'brightness': 1,
#  'age': 1,
#  'Colossus': 1,
#  'skin': 1,
#  'took': 1,
#  'longer': 1,
#  'manifest': 2,
#  'morning': 1,
#  'Beast': 1,
#  'declines': 1,
#  'noting': 1,
#  'cellular': 1,
#  'efficiency': 1,
#  'drops': 1,
#  'points': 1,
#  '0.9': 1,
#  '1.3': 1,
#  '1.8': 1,
#  'entropy': 1,
#  'slow': 1,
#  'motion': 1,
#  'built': 1,
#  'Forge': 1,
#  'designed': 1,
#  'drone': 1,
#  'size': 1,
#  'fingernail': 1,
#  'map': 1,
#  'city': 3,
#  'thirty': 1,
#  'flew': 1,
#  'perfectly': 1,
#  'exploded': 1,
#  'midair': 1,
#  'debris': 1,
#  'weighed': 1,
#  'feather': 1,
#  'replicate': 1,
#  'Records': 1,
#  'births': 1,
#  'high': 1,
#  'energy': 1,
#  'events': 1,
#  'flares': 1,
#  'nuclear': 1,
#  'tests': 1,
#  '’': 1,
#  '94': 1,
#  'plotted': 1,
#  'timeline': 1,
#  'fractal': 1,
#  'patterns': 1,
#  'repeating': 1,
#  'gap': 1,
#  'lengths': 1,
#  'rises': 1,
#  'cycle': 1,
#  'hiding': 1,
#  'plain': 1,
#  'sighting': 1,
#  'Mystique': 1,
#  'battlefield': 1,
#  'small': 1,
#  'train': 3,
#  'station': 1,
#  'rural': 1,
#  'France': 1,
#  'CCTV': 1,
#  'caught': 1,
#  'past': 1,
#  'ticket': 1,
#  'booth': 1,
#  'face': 2,
#  'unshifted': 1,
#  'book': 1,
#  'title': 1,
#  'cover': 1,
#  'boarded': 1,
#  'sat': 1,
#  'window': 1,
#  'vanished': 1,
#  'emerged': 1,
#  'tunnel': 1,
#  'Mutants': 8,
#  'powerful': 1,
#  'proof': 4,
#  'humanity': 4,
#  'grow': 1,
#  'limits': 1,
#  'rely': 1,
#  'gadgets': 1,
#  'alien': 3,
#  'bloodlines': 1,
#  'abilities': 4,
#  'stitched': 1,
#  'DNA': 1,
#  'makes': 1,
#  'heroism': 2,
#  'feel': 1,
#  'personal': 1,
#  'saves': 3,
#  'mask': 1,
#  'machine': 2,
#  'work': 1,
#  'body': 1,
#  'soul': 1,
#  'People': 2,
#  'admire': 1,
#  'born': 3,
#  'weight': 1,
#  'handle': 1,
#  'ordinary': 1,
#  'grew': 1,
#  'different': 3,
#  'learned': 1,
#  'control': 4,
#  'dangerous': 2,
#  'gifts': 1,
#  'chose': 1,
#  'help': 2,
#  'resilience': 1,
#  'earns': 1,
#  'respect': 2,
#  'Everyday': 1,
#  'citizens': 2,
#  'easily': 1,
#  'heroes': 3,
#  'planet': 2,
#  'buy': 1,
#  'way': 1,
#  'super': 1,
#  'strength': 1,
#  'idea': 1,
#  'evolution': 3,
#  'potential': 1,
#  'great': 1,
#  'inspiring': 1,
#  'people': 5,
#  'accident': 2,
#  'destiny': 1,
#  'steps': 1,
#  'stop': 2,
#  'crowd': 1,
#  'knows': 1,
#  'display': 1,
#  'living': 2,
#  'future': 3,
#  'fear': 4,
#  'look': 1,
#  'forward': 2,
#  'choose': 1,
#  'wait': 1,
#  'cosmic': 1,
#  'event': 1,
#  'awaken': 1,
#  'naturally': 1,
#  'childhood': 1,
#  'terrifies': 1,
#  'hero': 2,
#  'armor': 1,
#  'man': 1,
#  'entirely': 1,
#  'nature': 1,
#  'rewrite': 1,
#  'rules': 1,
#  'easier': 1,
#  'trust': 1,
#  'explanation': 1,
#  'soldier': 1,
#  'suit': 2,
#  'scientist': 1,
#  'bitten': 1,
#  'strange': 2,
#  'stories': 1,
#  'beginnings': 1,
#  'boundaries': 1,
#  'origins': 1,
#  'tangled': 1,
#  'biology': 1,
#  'genetics': 1,
#  'whispers': 1,
#  'means': 1,
#  'knowing': 1,
#  'uncertainty': 1,
#  'breeds': 1,
#  'Fear': 1,
#  'turns': 1,
#  'prejudice': 1,
#  'fast': 1,
#  'Newspapers': 1,
#  'talk': 1,
#  'individuals': 2,
#  'Politicians': 1,
#  'campaign': 1,
#  'promise': 1,
#  'registration': 1,
#  'Neighbors': 1,
#  'glance': 1,
#  'kid': 1,
#  'runs': 1,
#  'faster': 1,
#  'headlines': 2,
#  'focus': 1,
#  'destruction': 1,
#  'caused': 1,
#  'rescue': 1,
#  'parades': 1,
#  'Superheroes': 1,
#  'celebrated': 1,
#  'seen': 1,
#  'exceptional': 1,
#  'rare': 1,
#  'special': 1,
#  'chosen': 1,
#  'represent': 1,
#  'need': 1,
#  'fears': 1,
#  'sit': 1,
#  'place': 1,
#  'public': 2,
#  'mind': 1,
#  'push': 2,
#  'reminders': 1,
#  'changing': 1,
#  'ways': 1,
#  'time': 1,
#  'lives': 2,
#  'split': 1,
#  'celebrates': 1,
#  'asks': 1,
#  'trusted': 1,
#  'admiration': 1,
#  'easy': 1,
#  'understand': 1,
#  'spend': 1,
#  'check': 1,
#  'choosing': 1,
#  'risk': 1,
#  'protect': 1,
#  'strangers': 1,
#  'threats': 1,
#  'superhero': 1,
#  'support': 1,
#  'persistence': 1,
#  'hard': 1,
#  'comes': 1,
#  'masked': 1,
#  'vigilante': 1,
#  'hang': 1,
#  'fly': 1,
#  'home': 1,
#  'generation': 1,
#  'exciting': 1,
#  'glimpse': 1,
#  'humankind': 1,
#  'terrifying': 1,
#  'sign': 1,
#  'unrecognizable': 1,
#  'live': 1,
#  'constant': 1,
#  'pull': 1,
#  'acceptance': 1,
#  'suspicion': 2,
#  'Loved': 1,
#  'cities': 1,
#  'feared': 1,
#  'aware': 1,
#  'single': 1,
#  'tip': 1,
#  'balance': 1,
#  'ask': 1,
#  'treats': 1,
#  'cape': 1,
#  'gets': 2,
#  'parade': 1,
#  'police': 1,
#  'escort': 1,
#  '…': 1,
#  'switch': 1,
#  'hand': 1,
#  'question': 1,
#  'mark': 1,
#  'humans': 1,
#  'hate': 1,
#  'unanswered': 1,
#  'questions': 1,
#  'irony': 1,
#  'want': 1,
#  'thing': 1,
#  'Friends': 1,
#  'Peace': 1,
#  'Safety': 1,
#  'second': 1,
#  'genes': 1,
#  'reveal': 1,
#  'extraordinary': 1,
#  'dream': 1,
#  'burns': 1,
#  'cheer': 1,
#  'jeer': 1,
#  'handshake': 1,
#  'locked': 1,
#  'door': 1,
#  'decide': 1,
#  'saviors': 1,
#  'wave': 1,
#  'worse': 1}

# %%
len(word_frequencies)
# Out:
# 778

# %%
max_frequency = max(word_frequencies.values())
max_frequency
# Out:
# 35

# %%
# Token Scoring

for word in word_frequencies.keys():
    word_frequencies[word] = word_frequencies[word]/max_frequency

# %%
word_frequencies
# Out:
# {'called': 0.05714285714285714,
#  'mutants': 0.34285714285714286,
#  'long': 0.11428571428571428,
#  'agreed': 0.02857142857142857,
#  'Magneto': 0.05714285714285714,
#  'Erik': 0.02857142857142857,
#  'Lehnsherr': 0.02857142857142857,
#  'said': 0.05714285714285714,
#  'problem': 0.05714285714285714,
#  'solution': 0.02857142857142857,
#  'predict': 0.11428571428571428,
#  '1973': 0.05714285714285714,
#  'incident': 0.02857142857142857,
#  'Lab-9': 0.02857142857142857,
#  'field': 0.02857142857142857,
#  'surge': 0.02857142857142857,
#  'flipped': 0.02857142857142857,
#  'labs': 0.02857142857142857,
#  'meeting': 0.02857142857142857,
#  'room': 0.08571428571428572,
#  'static': 0.02857142857142857,
#  'soup': 0.02857142857142857,
#  'staff': 0.02857142857142857,
#  'logged': 0.02857142857142857,
#  '11': 0.02857142857142857,
#  '06': 0.02857142857142857,
#  '03:14': 0.02857142857142857,
#  'UTC': 0.02857142857142857,
#  'Victims': 0.02857142857142857,
#  'recovered': 0.02857142857142857,
#  'Sample': 0.02857142857142857,
#  'IDs': 0.02857142857142857,
#  'X-002': 0.02857142857142857,
#  'X23': 0.02857142857142857,
#  'A.': 0.02857142857142857,
#  '\n\n': 1.0,
#  'Jean': 0.02857142857142857,
#  'Grey': 0.02857142857142857,
#  'woke': 0.02857142857142857,
#  'taste': 0.02857142857142857,
#  'ozone': 0.02857142857142857,
#  'headache': 0.02857142857142857,
#  'felt': 0.02857142857142857,
#  'like': 0.2571428571428571,
#  'rearranged': 0.02857142857142857,
#  'skull': 0.02857142857142857,
#  'whispered': 0.02857142857142857,
#  'Telepathy': 0.02857142857142857,
#  'telekinesis': 0.02857142857142857,
#  'occasional': 0.02857142857142857,
#  'reality': 0.05714285714285714,
#  'hiccup': 0.02857142857142857,
#  'bad': 0.05714285714285714,
#  'sleep': 0.02857142857142857,
#  'deprived': 0.02857142857142857,
#  'mood': 0.02857142857142857,
#  'swings': 0.02857142857142857,
#  'odds': 0.02857142857142857,
#  'catastrophe': 0.02857142857142857,
#  'rose': 0.05714285714285714,
#  'sharply': 0.02857142857142857,
#  'Project': 0.02857142857142857,
#  'Phoenix': 0.02857142857142857,
#  'mentioned': 0.02857142857142857,
#  'files': 0.05714285714285714,
#  'followed': 0.02857142857142857,
#  'emergency': 0.02857142857142857,
#  'protocols': 0.02857142857142857,
#  'red': 0.02857142857142857,
#  'ink': 0.02857142857142857,
#  'Historical': 0.02857142857142857,
#  'records': 0.08571428571428572,
#  'power': 0.08571428571428572,
#  'states': 0.02857142857142857,
#  'latent': 0.02857142857142857,
#  'powers': 0.2,
#  'stayed': 0.05714285714285714,
#  'hidden': 0.08571428571428572,
#  'unknown': 0.05714285714285714,
#  'trigger': 0.02857142857142857,
#  'forced': 0.02857142857142857,
#  'active': 0.02857142857142857,
#  'worked': 0.02857142857142857,
#  'predictably': 0.02857142857142857,
#  'clockwork': 0.02857142857142857,
#  'volatile': 0.02857142857142857,
#  'refused': 0.02857142857142857,
#  'pattern': 0.02857142857142857,
#  'requiring': 0.02857142857142857,
#  'strict': 0.02857142857142857,
#  'containment': 0.05714285714285714,
#  'Lead': 0.02857142857142857,
#  'lined': 0.02857142857142857,
#  'chambers': 0.05714285714285714,
#  'industrial': 0.02857142857142857,
#  'foam': 0.02857142857142857,
#  'total': 0.02857142857142857,
#  'silence': 0.05714285714285714,
#  'common': 0.02857142857142857,
#  'safety': 0.02857142857142857,
#  'measures': 0.02857142857142857,
#  'worst': 0.02857142857142857,
#  'mistake': 0.02857142857142857,
#  'introducing': 0.02857142857142857,
#  'water': 0.02857142857142857,
#  'near': 0.02857142857142857,
#  'electrical': 0.02857142857142857,
#  'mutant': 0.34285714285714286,
#  'rule': 0.02857142857142857,
#  'broken': 0.05714285714285714,
#  'times': 0.05714285714285714,
#  'Reed': 0.02857142857142857,
#  'claimed': 0.08571428571428572,
#  'lattice': 0.02857142857142857,
#  'hold': 0.02857142857142857,
#  'negative': 0.02857142857142857,
#  'degrees': 0.02857142857142857,
#  'Celsius': 0.02857142857142857,
#  'feedline': 0.02857142857142857,
#  'remained': 0.02857142857142857,
#  'untouched': 0.02857142857142857,
#  'Hank': 0.02857142857142857,
#  'believed': 0.02857142857142857,
#  'saying': 0.02857142857142857,
#  'sentence': 0.02857142857142857,
#  'started': 0.05714285714285714,
#  'ended': 0.11428571428571428,
#  'invitation': 0.02857142857142857,
#  'disaster': 0.05714285714285714,
#  'practice': 0.02857142857142857,
#  'knew': 0.02857142857142857,
#  'truth': 0.05714285714285714,
#  '—': 0.4,
#  'held': 0.02857142857142857,
#  'hyphenated': 0.02857142857142857,
#  'words': 0.05714285714285714,
#  'scribbled': 0.02857142857142857,
#  'margins': 0.02857142857142857,
#  'reports': 0.08571428571428572,
#  'mother': 0.02857142857142857,
#  'law': 0.02857142857142857,
#  'jokes': 0.02857142857142857,
#  'sense': 0.02857142857142857,
#  'X': 0.02857142857142857,
#  'men': 0.02857142857142857,
#  'written': 0.02857142857142857,
#  'block': 0.05714285714285714,
#  'capitals': 0.02857142857142857,
#  'numbers': 0.05714285714285714,
#  '3.14': 0.02857142857142857,
#  '1e6': 0.02857142857142857,
#  'data': 0.08571428571428572,
#  'random': 0.02857142857142857,
#  'email': 0.02857142857142857,
#  'addresses': 0.02857142857142857,
#  'professor.x@academy.org': 0.02857142857142857,
#  'links': 0.02857142857142857,
#  'half': 0.02857142857142857,
#  'archives': 0.02857142857142857,
#  'Ellipses': 0.02857142857142857,
#  'marked': 0.05714285714285714,
#  'sudden': 0.05714285714285714,
#  'stops': 0.02857142857142857,
#  'parentheses': 0.02857142857142857,
#  'spiraled': 0.02857142857142857,
#  'nested': 0.02857142857142857,
#  'loops': 0.02857142857142857,
#  'tell': 0.02857142857142857,
#  'thought': 0.02857142857142857,
#  'began': 0.02857142857142857,
#  'surviving': 0.02857142857142857,
#  'entry': 0.05714285714285714,
#  'Mutant': 0.02857142857142857,
#  'Archive': 0.02857142857142857,
#  'warning': 0.02857142857142857,
#  'Stay': 0.05714285714285714,
#  'alive': 0.02857142857142857,
#  'stay': 0.02857142857142857,
#  'rest': 0.02857142857142857,
#  'world': 0.17142857142857143,
#  'care': 0.02857142857142857,
#  'choice': 0.05714285714285714,
#  '1986': 0.02857142857142857,
#  'island': 0.02857142857142857,
#  'Genosha': 0.02857142857142857,
#  'Satellite': 0.05714285714285714,
#  'scans': 0.02857142857142857,
#  'proved': 0.02857142857142857,
#  'Thermal': 0.02857142857142857,
#  'anomalies': 0.05714285714285714,
#  'underground': 0.02857142857142857,
#  'averaging': 0.02857142857142857,
#  'meters': 0.02857142857142857,
#  'surface': 0.02857142857142857,
#  'Reports': 0.02857142857142857,
#  'found': 0.05714285714285714,
#  'encrypted': 0.02857142857142857,
#  'drive': 0.02857142857142857,
#  'spoke': 0.02857142857142857,
#  'collars': 0.02857142857142857,
#  'tagged': 0.02857142857142857,
#  'MK': 0.02857142857142857,
#  'IV': 0.02857142857142857,
#  'restricting': 0.02857142857142857,
#  'cortical': 0.02857142857142857,
#  'spikes': 0.05714285714285714,
#  '0.7': 0.02857142857142857,
#  'millivolts': 0.02857142857142857,
#  'logs': 0.05714285714285714,
#  'named': 0.02857142857142857,
#  'captives': 0.02857142857142857,
#  '402': 0.02857142857142857,
#  '718': 0.02857142857142857,
#  '719B.': 0.02857142857142857,
#  'Storm': 0.02857142857142857,
#  'hated': 0.05714285714285714,
#  'confined': 0.02857142857142857,
#  'air': 0.02857142857142857,
#  'metal': 0.05714285714285714,
#  'corridors': 0.02857142857142857,
#  'submersible': 0.02857142857142857,
#  'pressed': 0.02857142857142857,
#  'senses': 0.02857142857142857,
#  'steel': 0.08571428571428572,
#  'coffin': 0.02857142857142857,
#  'Pressure': 0.02857142857142857,
#  'readings': 0.02857142857142857,
#  'dive': 0.02857142857142857,
#  'weather': 0.02857142857142857,
#  'instincts': 0.02857142857142857,
#  'fought': 0.05714285714285714,
#  'Atlantic': 0.02857142857142857,
#  'calm': 0.02857142857142857,
#  'bones': 0.02857142857142857,
#  'ached': 0.02857142857142857,
#  'storm': 0.02857142857142857,
#  'loomed': 0.02857142857142857,
#  'sight': 0.05714285714285714,
#  'Scott': 0.02857142857142857,
#  'told': 0.02857142857142857,
#  'head': 0.02857142857142857,
#  'believe': 0.05714285714285714,
#  'training': 0.08571428571428572,
#  'simulations': 0.02857142857142857,
#  'probability': 0.02857142857142857,
#  'curves': 0.02857142857142857,
#  'rarely': 0.02857142857142857,
#  'matched': 0.02857142857142857,
#  'model': 0.02857142857142857,
#  '85': 0.02857142857142857,
#  'chance': 0.02857142857142857,
#  'target': 0.02857142857142857,
#  'neutralization': 0.02857142857142857,
#  'coin': 0.02857142857142857,
#  'dropped': 0.02857142857142857,
#  'wrong': 0.02857142857142857,
#  'moment': 0.08571428571428572,
#  'throw': 0.02857142857142857,
#  'result': 0.02857142857142857,
#  'zero': 0.02857142857142857,
#  'Logan': 0.02857142857142857,
#  'treated': 0.02857142857142857,
#  'probabilities': 0.02857142857142857,
#  'polite': 0.02857142857142857,
#  'lies': 0.02857142857142857,
#  'useful': 0.02857142857142857,
#  'fight': 0.08571428571428572,
#  'claws': 0.02857142857142857,
#  'better': 0.02857142857142857,
#  'arguments': 0.02857142857142857,
#  'statistical': 0.02857142857142857,
#  'forecast': 0.02857142857142857,
#  'figured': 0.02857142857142857,
#  'Westchester': 0.02857142857142857,
#  'alarm': 0.05714285714285714,
#  'tripped': 0.02857142857142857,
#  'exactly': 0.02857142857142857,
#  '02:13': 0.02857142857142857,
#  'Thursday': 0.02857142857142857,
#  'Maintenance': 0.02857142857142857,
#  'replaced': 0.02857142857142857,
#  'wiring': 0.02857142857142857,
#  'swapped': 0.02857142857142857,
#  'backup': 0.02857142857142857,
#  'generator': 0.02857142857142857,
#  'gutted': 0.02857142857142857,
#  'entire': 0.05714285714285714,
#  'subpanel': 0.02857142857142857,
#  'kept': 0.05714285714285714,
#  'ringing': 0.02857142857142857,
#  'timestamp': 0.02857142857142857,
#  'cutting': 0.02857142857142857,
#  '41': 0.02857142857142857,
#  'seconds': 0.05714285714285714,
#  'Xavier': 0.02857142857142857,
#  'wrote': 0.05714285714285714,
#  'log': 0.02857142857142857,
#  'things': 0.05714285714285714,
#  'fixing': 0.02857142857142857,
#  'Cerebro': 0.02857142857142857,
#  'showed': 0.02857142857142857,
#  'language': 0.05714285714285714,
#  'young': 0.02857142857142857,
#  'speak': 0.02857142857142857,
#  'dialects': 0.02857142857142857,
#  'hours': 0.02857142857142857,
#  'exposure': 0.02857142857142857,
#  'communicate': 0.02857142857142857,
#  'palindromes': 0.02857142857142857,
#  'Written': 0.02857142857142857,
#  'contained': 0.02857142857142857,
#  'oddities': 0.02857142857142857,
#  '“': 0.22857142857142856,
#  'madam': 0.02857142857142857,
#  'adam': 0.02857142857142857,
#  '”': 0.22857142857142856,
#  'repeated': 0.02857142857142857,
#  'row': 0.02857142857142857,
#  'apparent': 0.02857142857142857,
#  'meaning': 0.02857142857142857,
#  'Linguists': 0.02857142857142857,
#  'left': 0.05714285714285714,
#  'confused': 0.02857142857142857,
#  'telepaths': 0.02857142857142857,
#  'silent': 0.02857142857142857,
#  '1999': 0.02857142857142857,
#  'blackout': 0.05714285714285714,
#  'Eastern': 0.02857142857142857,
#  'Europe': 0.02857142857142857,
#  'lasted': 0.02857142857142857,
#  'seventeen': 0.02857142857142857,
#  'minutes': 0.05714285714285714,
#  'noted': 0.02857142857142857,
#  'solar': 0.05714285714285714,
#  'flare': 0.05714285714285714,
#  'geomagnetic': 0.02857142857142857,
#  'spike': 0.02857142857142857,
#  'explainable': 0.02857142857142857,
#  'cause': 0.02857142857142857,
#  'Files': 0.02857142857142857,
#  'later': 0.05714285714285714,
#  'surfaced': 0.02857142857142857,
#  'referencing': 0.02857142857142857,
#  'Subject': 0.02857142857142857,
#  'Theta-7': 0.02857142857142857,
#  'able': 0.02857142857142857,
#  'bend': 0.02857142857142857,
#  'electromagnetic': 0.02857142857142857,
#  'fields': 0.02857142857142857,
#  'concentration': 0.02857142857142857,
#  'Witness': 0.02857142857142857,
#  'accounts': 0.02857142857142857,
#  'conflicted': 0.02857142857142857,
#  'boy': 0.02857142857142857,
#  'rubble': 0.02857142857142857,
#  'swore': 0.02857142857142857,
#  'Energy': 0.02857142857142857,
#  'signatures': 0.02857142857142857,
#  'burned': 0.02857142857142857,
#  'scars': 0.02857142857142857,
#  'unexplained': 0.05714285714285714,
#  'decades': 0.05714285714285714,
#  'Jubilee': 0.02857142857142857,
#  'described': 0.02857142857142857,
#  'life': 0.05714285714285714,
#  'walking': 0.11428571428571428,
#  'carrying': 0.11428571428571428,
#  'fireworks': 0.02857142857142857,
#  'asked': 0.02857142857142857,
#  'included': 0.02857142857142857,
#  'timestamps': 0.02857142857142857,
#  'discharge': 0.02857142857142857,
#  'levels': 0.02857142857142857,
#  'stress': 0.02857142857142857,
#  'ratings': 0.02857142857142857,
#  'important': 0.02857142857142857,
#  'detail': 0.02857142857142857,
#  'technical': 0.02857142857142857,
#  'sparks': 0.02857142857142857,
#  'children': 0.02857142857142857,
#  'laugh': 0.02857142857142857,
#  'shelters': 0.02857142857142857,
#  'hope': 0.02857142857142857,
#  'short': 0.02857142857142857,
#  'supply': 0.02857142857142857,
#  'Analysts': 0.05714285714285714,
#  'flagged': 0.02857142857142857,
#  'non': 0.08571428571428572,
#  'essential': 0.02857142857142857,
#  'record': 0.02857142857142857,
#  'Warpath': 0.02857142857142857,
#  'unfiltered': 0.02857142857142857,
#  'filled': 0.02857142857142857,
#  'metaphors': 0.02857142857142857,
#  'instead': 0.02857142857142857,
#  'measurements': 0.02857142857142857,
#  'compared': 0.02857142857142857,
#  'halls': 0.02857142857142857,
#  'caves': 0.02857142857142857,
#  'echoing': 0.02857142857142857,
#  'tactical': 0.02857142857142857,
#  'drills': 0.02857142857142857,
#  'storms': 0.02857142857142857,
#  'waiting': 0.02857142857142857,
#  'permission': 0.02857142857142857,
#  'break': 0.02857142857142857,
#  'baffled': 0.02857142857142857,
#  'technicians': 0.02857142857142857,
#  'resonated': 0.02857142857142857,
#  'understood': 0.02857142857142857,
#  'dry': 0.02857142857142857,
#  'percentage': 0.05714285714285714,
#  'curve': 0.02857142857142857,
#  'revealed': 0.02857142857142857,
#  'charts': 0.02857142857142857,
#  '2005': 0.02857142857142857,
#  'geneticists': 0.02857142857142857,
#  'tracked': 0.02857142857142857,
#  'known': 0.05714285714285714,
#  'mutations': 0.02857142857142857,
#  'worldwide': 0.02857142857142857,
#  'mapped': 0.05714285714285714,
#  'alleles': 0.02857142857142857,
#  'cross': 0.02857142857142857,
#  'referenced': 0.02857142857142857,
#  'genomes': 0.02857142857142857,
#  'margin': 0.02857142857142857,
#  'error': 0.02857142857142857,
#  'wider': 0.02857142857142857,
#  'comfort': 0.02857142857142857,
#  'allowed': 0.02857142857142857,
#  'note': 0.02857142857142857,
#  'buried': 0.02857142857142857,
#  'read': 0.02857142857142857,
#  'Evolution': 0.02857142857142857,
#  'equation': 0.02857142857142857,
#  'tide': 0.02857142857142857,
#  'measure': 0.02857142857142857,
#  'waves': 0.02857142857142857,
#  'ocean': 0.02857142857142857,
#  'rise': 0.02857142857142857,
#  'prison': 0.02857142857142857,
#  'cell': 0.05714285714285714,
#  'technically': 0.02857142857142857,
#  'floating': 0.02857142857142857,
#  'suspended': 0.02857142857142857,
#  'ferrous': 0.02857142857142857,
#  'cables': 0.02857142857142857,
#  'saltwater': 0.02857142857142857,
#  'pit': 0.02857142857142857,
#  'bolt': 0.02857142857142857,
#  'weld': 0.02857142857142857,
#  'ceramic': 0.02857142857142857,
#  'Guards': 0.02857142857142857,
#  'rotated': 0.02857142857142857,
#  'ninety': 0.02857142857142857,
#  'avoid': 0.02857142857142857,
#  'familiarity': 0.02857142857142857,
#  'larger': 0.02857142857142857,
#  'paperclip': 0.02857142857142857,
#  'design': 0.02857142857142857,
#  'flawless': 0.02857142857142857,
#  'smuggled': 0.02857142857142857,
#  'simple': 0.02857142857142857,
#  'belt': 0.02857142857142857,
#  'buckle': 0.02857142857142857,
#  'aged': 0.02857142857142857,
#  'hosts': 0.02857142857142857,
#  'Pyro': 0.02857142857142857,
#  'flames': 0.02857142857142857,
#  'lost': 0.02857142857142857,
#  'brightness': 0.02857142857142857,
#  'age': 0.02857142857142857,
#  'Colossus': 0.02857142857142857,
#  'skin': 0.02857142857142857,
#  'took': 0.02857142857142857,
#  'longer': 0.02857142857142857,
#  'manifest': 0.05714285714285714,
#  'morning': 0.02857142857142857,
#  'Beast': 0.02857142857142857,
#  'declines': 0.02857142857142857,
#  'noting': 0.02857142857142857,
#  'cellular': 0.02857142857142857,
#  'efficiency': 0.02857142857142857,
#  'drops': 0.02857142857142857,
#  'points': 0.02857142857142857,
#  '0.9': 0.02857142857142857,
#  '1.3': 0.02857142857142857,
#  '1.8': 0.02857142857142857,
#  'entropy': 0.02857142857142857,
#  'slow': 0.02857142857142857,
#  'motion': 0.02857142857142857,
#  'built': 0.02857142857142857,
#  'Forge': 0.02857142857142857,
#  'designed': 0.02857142857142857,
#  'drone': 0.02857142857142857,
#  'size': 0.02857142857142857,
#  'fingernail': 0.02857142857142857,
#  'map': 0.02857142857142857,
#  'city': 0.08571428571428572,
#  'thirty': 0.02857142857142857,
#  'flew': 0.02857142857142857,
#  'perfectly': 0.02857142857142857,
#  'exploded': 0.02857142857142857,
#  'midair': 0.02857142857142857,
#  'debris': 0.02857142857142857,
#  'weighed': 0.02857142857142857,
#  'feather': 0.02857142857142857,
#  'replicate': 0.02857142857142857,
#  'Records': 0.02857142857142857,
#  'births': 0.02857142857142857,
#  'high': 0.02857142857142857,
#  'energy': 0.02857142857142857,
#  'events': 0.02857142857142857,
#  'flares': 0.02857142857142857,
#  'nuclear': 0.02857142857142857,
#  'tests': 0.02857142857142857,
#  '’': 0.02857142857142857,
#  '94': 0.02857142857142857,
#  'plotted': 0.02857142857142857,
#  'timeline': 0.02857142857142857,
#  'fractal': 0.02857142857142857,
#  'patterns': 0.02857142857142857,
#  'repeating': 0.02857142857142857,
#  'gap': 0.02857142857142857,
#  'lengths': 0.02857142857142857,
#  'rises': 0.02857142857142857,
#  'cycle': 0.02857142857142857,
#  'hiding': 0.02857142857142857,
#  'plain': 0.02857142857142857,
#  'sighting': 0.02857142857142857,
#  'Mystique': 0.02857142857142857,
#  'battlefield': 0.02857142857142857,
#  'small': 0.02857142857142857,
#  'train': 0.08571428571428572,
#  'station': 0.02857142857142857,
#  'rural': 0.02857142857142857,
#  'France': 0.02857142857142857,
#  'CCTV': 0.02857142857142857,
#  'caught': 0.02857142857142857,
#  'past': 0.02857142857142857,
#  'ticket': 0.02857142857142857,
#  'booth': 0.02857142857142857,
#  'face': 0.05714285714285714,
#  'unshifted': 0.02857142857142857,
#  'book': 0.02857142857142857,
#  'title': 0.02857142857142857,
#  'cover': 0.02857142857142857,
#  'boarded': 0.02857142857142857,
#  'sat': 0.02857142857142857,
#  'window': 0.02857142857142857,
#  'vanished': 0.02857142857142857,
#  'emerged': 0.02857142857142857,
#  'tunnel': 0.02857142857142857,
#  'Mutants': 0.22857142857142856,
#  'powerful': 0.02857142857142857,
#  'proof': 0.11428571428571428,
#  'humanity': 0.11428571428571428,
#  'grow': 0.02857142857142857,
#  'limits': 0.02857142857142857,
#  'rely': 0.02857142857142857,
#  'gadgets': 0.02857142857142857,
#  'alien': 0.08571428571428572,
#  'bloodlines': 0.02857142857142857,
#  'abilities': 0.11428571428571428,
#  'stitched': 0.02857142857142857,
#  'DNA': 0.02857142857142857,
#  'makes': 0.02857142857142857,
#  'heroism': 0.05714285714285714,
#  'feel': 0.02857142857142857,
#  'personal': 0.02857142857142857,
#  'saves': 0.08571428571428572,
#  'mask': 0.02857142857142857,
#  'machine': 0.05714285714285714,
#  'work': 0.02857142857142857,
#  'body': 0.02857142857142857,
#  'soul': 0.02857142857142857,
#  'People': 0.05714285714285714,
#  'admire': 0.02857142857142857,
#  'born': 0.08571428571428572,
#  'weight': 0.02857142857142857,
#  'handle': 0.02857142857142857,
#  'ordinary': 0.02857142857142857,
#  'grew': 0.02857142857142857,
#  'different': 0.08571428571428572,
#  'learned': 0.02857142857142857,
#  'control': 0.11428571428571428,
#  'dangerous': 0.05714285714285714,
#  'gifts': 0.02857142857142857,
#  'chose': 0.02857142857142857,
#  'help': 0.05714285714285714,
#  'resilience': 0.02857142857142857,
#  'earns': 0.02857142857142857,
#  'respect': 0.05714285714285714,
#  'Everyday': 0.02857142857142857,
#  'citizens': 0.05714285714285714,
#  'easily': 0.02857142857142857,
#  'heroes': 0.08571428571428572,
#  'planet': 0.05714285714285714,
#  'buy': 0.02857142857142857,
#  'way': 0.02857142857142857,
#  'super': 0.02857142857142857,
#  'strength': 0.02857142857142857,
#  'idea': 0.02857142857142857,
#  'evolution': 0.08571428571428572,
#  'potential': 0.02857142857142857,
#  'great': 0.02857142857142857,
#  'inspiring': 0.02857142857142857,
#  'people': 0.14285714285714285,
#  'accident': 0.05714285714285714,
#  'destiny': 0.02857142857142857,
#  'steps': 0.02857142857142857,
#  'stop': 0.05714285714285714,
#  'crowd': 0.02857142857142857,
#  'knows': 0.02857142857142857,
#  'display': 0.02857142857142857,
#  'living': 0.05714285714285714,
#  'future': 0.08571428571428572,
#  'fear': 0.11428571428571428,
#  'look': 0.02857142857142857,
#  'forward': 0.05714285714285714,
#  'choose': 0.02857142857142857,
#  'wait': 0.02857142857142857,
#  'cosmic': 0.02857142857142857,
#  'event': 0.02857142857142857,
#  'awaken': 0.02857142857142857,
#  'naturally': 0.02857142857142857,
#  'childhood': 0.02857142857142857,
#  'terrifies': 0.02857142857142857,
#  'hero': 0.05714285714285714,
#  'armor': 0.02857142857142857,
#  'man': 0.02857142857142857,
#  'entirely': 0.02857142857142857,
#  'nature': 0.02857142857142857,
#  'rewrite': 0.02857142857142857,
#  'rules': 0.02857142857142857,
#  'easier': 0.02857142857142857,
#  'trust': 0.02857142857142857,
#  'explanation': 0.02857142857142857,
#  'soldier': 0.02857142857142857,
#  'suit': 0.05714285714285714,
#  'scientist': 0.02857142857142857,
#  'bitten': 0.02857142857142857,
#  'strange': 0.05714285714285714,
#  'stories': 0.02857142857142857,
#  'beginnings': 0.02857142857142857,
#  'boundaries': 0.02857142857142857,
#  'origins': 0.02857142857142857,
#  'tangled': 0.02857142857142857,
#  'biology': 0.02857142857142857,
#  'genetics': 0.02857142857142857,
#  'whispers': 0.02857142857142857,
#  'means': 0.02857142857142857,
#  'knowing': 0.02857142857142857,
#  'uncertainty': 0.02857142857142857,
#  'breeds': 0.02857142857142857,
#  'Fear': 0.02857142857142857,
#  'turns': 0.02857142857142857,
#  'prejudice': 0.02857142857142857,
#  'fast': 0.02857142857142857,
#  'Newspapers': 0.02857142857142857,
#  'talk': 0.02857142857142857,
#  'individuals': 0.05714285714285714,
#  'Politicians': 0.02857142857142857,
#  'campaign': 0.02857142857142857,
#  'promise': 0.02857142857142857,
#  'registration': 0.02857142857142857,
#  'Neighbors': 0.02857142857142857,
#  'glance': 0.02857142857142857,
#  'kid': 0.02857142857142857,
#  'runs': 0.02857142857142857,
#  'faster': 0.02857142857142857,
#  'headlines': 0.05714285714285714,
#  'focus': 0.02857142857142857,
#  'destruction': 0.02857142857142857,
#  'caused': 0.02857142857142857,
#  'rescue': 0.02857142857142857,
#  'parades': 0.02857142857142857,
#  'Superheroes': 0.02857142857142857,
#  'celebrated': 0.02857142857142857,
#  'seen': 0.02857142857142857,
#  'exceptional': 0.02857142857142857,
#  'rare': 0.02857142857142857,
#  'special': 0.02857142857142857,
#  'chosen': 0.02857142857142857,
#  'represent': 0.02857142857142857,
#  'need': 0.02857142857142857,
#  'fears': 0.02857142857142857,
#  'sit': 0.02857142857142857,
#  'place': 0.02857142857142857,
#  'public': 0.05714285714285714,
#  'mind': 0.02857142857142857,
#  'push': 0.05714285714285714,
#  'reminders': 0.02857142857142857,
#  'changing': 0.02857142857142857,
#  'ways': 0.02857142857142857,
#  'time': 0.02857142857142857,
#  'lives': 0.05714285714285714,
#  'split': 0.02857142857142857,
#  'celebrates': 0.02857142857142857,
#  'asks': 0.02857142857142857,
#  'trusted': 0.02857142857142857,
#  'admiration': 0.02857142857142857,
#  'easy': 0.02857142857142857,
#  'understand': 0.02857142857142857,
#  'spend': 0.02857142857142857,
#  'check': 0.02857142857142857,
#  'choosing': 0.02857142857142857,
#  'risk': 0.02857142857142857,
#  'protect': 0.02857142857142857,
#  'strangers': 0.02857142857142857,
#  'threats': 0.02857142857142857,
#  'superhero': 0.02857142857142857,
#  'support': 0.02857142857142857,
#  'persistence': 0.02857142857142857,
#  'hard': 0.02857142857142857,
#  'comes': 0.02857142857142857,
#  'masked': 0.02857142857142857,
#  'vigilante': 0.02857142857142857,
#  'hang': 0.02857142857142857,
#  'fly': 0.02857142857142857,
#  'home': 0.02857142857142857,
#  'generation': 0.02857142857142857,
#  'exciting': 0.02857142857142857,
#  'glimpse': 0.02857142857142857,
#  'humankind': 0.02857142857142857,
#  'terrifying': 0.02857142857142857,
#  'sign': 0.02857142857142857,
#  'unrecognizable': 0.02857142857142857,
#  'live': 0.02857142857142857,
#  'constant': 0.02857142857142857,
#  'pull': 0.02857142857142857,
#  'acceptance': 0.02857142857142857,
#  'suspicion': 0.05714285714285714,
#  'Loved': 0.02857142857142857,
#  'cities': 0.02857142857142857,
#  'feared': 0.02857142857142857,
#  'aware': 0.02857142857142857,
#  'single': 0.02857142857142857,
#  'tip': 0.02857142857142857,
#  'balance': 0.02857142857142857,
#  'ask': 0.02857142857142857,
#  'treats': 0.02857142857142857,
#  'cape': 0.02857142857142857,
#  'gets': 0.05714285714285714,
#  'parade': 0.02857142857142857,
#  'police': 0.02857142857142857,
#  'escort': 0.02857142857142857,
#  '…': 0.02857142857142857,
#  'switch': 0.02857142857142857,
#  'hand': 0.02857142857142857,
#  'question': 0.02857142857142857,
#  'mark': 0.02857142857142857,
#  'humans': 0.02857142857142857,
#  'hate': 0.02857142857142857,
#  'unanswered': 0.02857142857142857,
#  'questions': 0.02857142857142857,
#  'irony': 0.02857142857142857,
#  'want': 0.02857142857142857,
#  'thing': 0.02857142857142857,
#  'Friends': 0.02857142857142857,
#  'Peace': 0.02857142857142857,
#  'Safety': 0.02857142857142857,
#  'second': 0.02857142857142857,
#  'genes': 0.02857142857142857,
#  'reveal': 0.02857142857142857,
#  'extraordinary': 0.02857142857142857,
#  'dream': 0.02857142857142857,
#  'burns': 0.02857142857142857,
#  'cheer': 0.02857142857142857,
#  'jeer': 0.02857142857142857,
#  'handshake': 0.02857142857142857,
#  'locked': 0.02857142857142857,
#  'door': 0.02857142857142857,
#  'decide': 0.02857142857142857,
#  'saviors': 0.02857142857142857,
#  'wave': 0.02857142857142857,
#  'worse': 0.02857142857142857}

# %%
# Sentence Tokenization

sentence_tokens = [sent for sent in doc.sents]
sentence_tokens
# Out:
# [They called them mutants long before anyone agreed on a name.,
#  Magneto, Erik Lehnsherr, once said we are not the problem, we are the solution.,
#  But even he couldn't predict the 1973 incident at Lab-9, when a field surge flipped three labs and a meeting room into static soup.,
#  The staff logged it as 1973-11-06, 03:14 UTC.,
#  Victims four, two recovered.,
#  Sample IDs X-002, X23-A.
#
#  Jean Grey woke up with the taste of ozone and a headache that felt like someone had rearranged her skull.,
#  Not again, she whispered to herself.,
#  Telepathy, telekinesis, and the occasional reality hiccup were bad enough, but with sleep-deprived mood swings the odds of catastrophe rose sharply.,
#  Project Phoenix was mentioned in the files, always followed by emergency protocols in red ink.
#  ,
#  Historical records show three power states: latent powers stayed hidden until some unknown trigger forced them out, active powers worked predictably like clockwork, and volatile powers refused any pattern at all, requiring strict containment.,
#  Lead-lined chambers, industrial foam, and total silence were common safety measures.,
#  The worst mistake was introducing water near an electrical mutant, and that rule was broken too many times.
#  ,
#  Reed once claimed that the lattice could hold at negative one hundred twenty degrees Celsius if the feedline remained untouched.,
#  Hank never believed him, saying any sentence that started with if and ended with should was an invitation for disaster.,
#  In practice, they both knew the truth — nothing ever held for long.
#  ,
#  There were always hyphenated words scribbled in the margins of reports, mother-in-law jokes that made no sense, X-men written in block capitals, numbers like 3.14 and 1e6 hidden in the data, random email addresses like professor.x@academy.org, and links to half-broken archives.,
#  Ellipses marked sudden stops, parentheses spiraled into nested loops, and no one could tell where one thought ended and the next began.
#  ,
#  The last surviving entry from the Mutant Archive ended with a warning.,
#  Stay alive.,
#  Stay hidden.,
#  Or stay together.,
#  The rest of the world will not care which choice you make.
#  ,
#  In 1986, the island of Genosha claimed it had no mutants.,
#  Satellite scans proved otherwise.,
#  Thermal anomalies marked twenty-three underground chambers, each averaging four meters below surface.,
#  Reports found on an encrypted drive spoke of collars tagged MK-IV, restricting cortical spikes to under 0.7 millivolts.,
#  The logs never named the captives, only numbers: 402, 718, 719B.
#
#  Storm hated confined air.,
#  The metal corridors of the submersible pressed on her senses like a steel coffin.,
#  Pressure readings rose with each dive, and her weather instincts fought the silence.,
#  The Atlantic above was calm, yet her bones ached as if a storm loomed just out of sight.,
#  Scott told her it was in her head.,
#  She didn’t believe him.
#  ,
#  In training simulations, probability curves rarely matched reality.,
#  A model might predict an 85% chance of target neutralization, yet a coin dropped in the wrong moment could throw the result to zero.,
#  Logan treated probabilities as polite lies — useful only until the fight started.,
#  His claws made better arguments than any statistical forecast.
#  ,
#  They never figured out why the Westchester alarm tripped at exactly 02:13 every third Thursday.,
#  Maintenance replaced wiring, swapped the backup generator, even gutted the entire subpanel.,
#  The alarm kept ringing, always the same timestamp, always cutting off after 41 seconds.,
#  Xavier wrote in his log that some things are not for fixing.
#  ,
#  Cerebro’s records showed language anomalies among young mutants.,
#  One could speak twelve dialects after two hours of exposure, another could only communicate in palindromes.,
#  Written reports contained oddities like “madam I’m adam” repeated fifty-three times in a row, with no apparent meaning.,
#  Linguists left confused, telepaths left silent.
#  ,
#  In 1999, a blackout across Eastern Europe lasted seventeen minutes.,
#  Satellite logs noted no solar flare, no geomagnetic spike, no explainable cause.,
#  Files later surfaced referencing “Subject Theta-7,” a mutant able to bend electromagnetic fields with nothing more than concentration.,
#  Witness accounts conflicted — some claimed to see a boy in the rubble, others swore no one was there at all.,
#  Energy signatures burned into the data like scars, still unexplained two decades later.
#  ,
#  Jubilee once described mutant life as “walking into every room carrying fireworks no one asked for.”,
#  Her files included timestamps, discharge levels, and even stress ratings before each flare.,
#  Yet the most important detail was never technical — it was that her sparks made children laugh in shelters where hope was short supply.,
#  Analysts flagged the entry as “non-essential,” but it stayed in the record anyway.
#  ,
#  Warpath wrote long, unfiltered reports filled with metaphors instead of measurements.,
#  He compared training halls to “caves echoing with steel,” and tactical drills to “storms waiting for permission to break.”,
#  His language baffled technicians but resonated with other mutants, who said they understood him more than any dry percentage or curve.,
#  Sometimes, his words revealed more truth than a hundred charts.
#  ,
#  By 2005, geneticists tracked more than three hundred known mutations worldwide.,
#  They mapped alleles, cross-referenced genomes, and still ended with a margin of error wider than comfort allowed.,
#  A note buried in the data read: Evolution is not an equation, it’s a tide.,
#  You can measure waves but never predict when the ocean will rise.
#  ,
#  Magneto’s prison cell was technically a floating room, suspended by non-ferrous cables over a saltwater pit.,
#  Every bolt and weld was ceramic.,
#  Guards rotated every ninety minutes to avoid familiarity, each carrying no metal larger than a paperclip.,
#  The design was flawless until someone smuggled in a simple belt buckle.
#  ,
#  Some powers aged with their hosts.,
#  Pyro’s flames lost brightness after age fifty, while Colossus’s steel skin took longer to manifest each morning.,
#  Beast kept records of these declines, noting cellular efficiency drops in percentage points: 0.9, 1.3, 1.8.,
#  He called it entropy in slow motion.
#  ,
#  Not all mutants fought.,
#  Some built.,
#  Forge once designed a drone the size of a fingernail that could map a city block in thirty seconds.,
#  It flew once, mapped perfectly, then exploded in midair.,
#  The debris weighed less than a feather.,
#  No one could replicate it.
#  ,
#  Records of mutant births show spikes after high-energy events: solar flares, nuclear tests, and the unexplained blackout of ’94.,
#  Analysts plotted them on a timeline and found fractal-like patterns, repeating across decades.,
#  The same gap lengths, the same sudden rises.,
#  A cycle hiding in plain sight.
#  ,
#  The last known sighting of Mystique was not on any battlefield but at a small train station in rural France.,
#  CCTV caught her walking past the ticket booth, face unshifted, carrying a book with no title on the cover.,
#  She boarded the train, sat by the window, and vanished when it emerged from the next tunnel.
#  ,
#  Mutants aren’t just powerful — they’re proof that humanity can grow beyond its limits.,
#  They don’t rely on gadgets or alien bloodlines.,
#  Their abilities are part of who they are, stitched into their DNA, and that makes their heroism feel more personal.,
#  When a mutant saves a city, it’s not a mask or a machine doing the work.,
#  It’s them, body and soul.
#  ,
#  People admire mutants because they were born carrying a weight most couldn’t handle.,
#  There’s no “before” for them — no moment where they were ordinary.,
#  They grew up different, learned to control dangerous gifts, and still chose to help a world that didn’t always help them.,
#  That resilience earns respect.
#  ,
#  Everyday citizens can see themselves in mutants more easily than in other heroes.,
#  You can’t train to be from another planet or buy your way into super strength, but the idea that evolution could give anyone the potential to do great things is inspiring.,
#  Mutants make people believe that heroism is not just an accident — it can be destiny.
#  ,
#  When a mutant steps in to stop a disaster, the crowd knows it’s more than just power on display.,
#  It’s living proof that humanity’s future might not be something to fear.,
#  It might be something to look forward to.
#  ,
#  Mutants are born different.,
#  They don’t choose their powers, and they don’t wait for an accident or a cosmic event to awaken them.,
#  Their abilities manifest naturally, often in childhood, and that alone terrifies people.,
#  A hero in armor is a man in a machine.,
#  A mutant is something else entirely — living proof that nature can rewrite the rules at will.
#  ,
#  For most citizens, it’s easier to trust heroes whose powers have an explanation.,
#  A soldier in a suit, a scientist bitten by something strange, an alien from another planet — those stories have beginnings and boundaries.,
#  Mutants have neither.,
#  Their origins are tangled in biology, genetics, and whispers of evolution, which means anyone, anywhere, could be one without knowing it yet.,
#  That uncertainty breeds fear.
#  ,
#  Fear turns into prejudice fast.,
#  Newspapers talk about mutants as a “problem,” not as individuals.,
#  Politicians campaign on the promise of registration.,
#  Neighbors glance too long at a kid who runs faster than he should.,
#  When a mutant saves a city, the headlines still focus on the destruction caused during the rescue.,
#  If a non-mutant does the same, they get parades.
#  ,
#  Superheroes are celebrated because they are seen as exceptional individuals — rare, special, chosen.,
#  Mutants are hated because they represent a future people can’t control.,
#  It’s not that the world doesn’t need them.,
#  It’s that the world fears it might become them.
#  ,
#  Mutants sit in a strange place in the public mind.,
#  To some, they’re heroes — proof that evolution can push humanity forward.,
#  To others, they’re walking reminders that the world is changing in ways no one can control.,
#  Every time a mutant saves lives, the headlines split: one side celebrates, the other asks if their powers make them too dangerous to be trusted.
#  ,
#  The admiration is easy to understand.,
#  Many mutants spend their entire lives training to keep their abilities in check, choosing to risk themselves to protect strangers.,
#  They face the same threats as any other superhero, but often without the public’s full support.,
#  That persistence is hard not to respect.
#  ,
#  The fear comes from the unknown.,
#  A masked vigilante can hang up the suit.,
#  An alien can fly home.,
#  But mutants can’t stop being what they are, and no one can predict what abilities the next generation will have.,
#  For some, that’s exciting — a glimpse into the future of humankind.,
#  For others, it’s terrifying — a sign that humanity might become something unrecognizable.
#  ,
#  And so, mutants live in this constant push and pull between acceptance and suspicion.,
#  Loved in some cities, feared in others, and always aware that a single bad moment could tip the balance.
#  ,
#  Mutants didn’t ask to be born different.,
#  But the world treats them like it’s a choice.,
#  A hero in a cape gets a parade.,
#  A mutant in the same fight gets a police escort… to a containment cell.
#  ,
#  It’s not about what they’ve done.,
#  It’s about what they could do.,
#  People fear that power they can’t switch off, can’t hand over, can’t control.,
#  Every mutant is a walking question mark, and humans hate unanswered questions.
#  ,
#  The irony?,
#  Most mutants want the same thing as everyone else — a life.,
#  Friends.,
#  Peace.,
#  Safety.,
#  But the second their genes reveal something extraordinary, that dream burns up in suspicion.
#  ,
#  For every cheer, there’s a jeer.,
#  For every handshake, there’s a locked door.,
#  Mutants fight for the people, but the people can’t decide if they’re saviors or the first wave of something worse.]

# %%
len(sentence_tokens)
# Out:
# 150

# %%
# Sentence Scoring

sentence_scores = {}

for sent in sentence_tokens:
    for word in sent:
        if word.text.lower() in word_frequencies.keys():
            if sent not in sentence_scores.keys():
                sentence_scores[sent] = word_frequencies[word.text.lower()]
            else:
                sentence_scores[sent] += word_frequencies[word.text.lower()]

sentence_scores
# Out:
# {They called them mutants long before anyone agreed on a name.: 0.5428571428571429,
#  Magneto, Erik Lehnsherr, once said we are not the problem, we are the solution.: 0.14285714285714285,
#  But even he couldn't predict the 1973 incident at Lab-9, when a field surge flipped three labs and a meeting room into static soup.: 0.48571428571428577,
#  The staff logged it as 1973-11-06, 03:14 UTC.: 0.2,
#  Victims four, two recovered.: 0.02857142857142857,
#  Sample IDs X-002, X23-A.
#
#  Jean Grey woke up with the taste of ozone and a headache that felt like someone had rearranged her skull.: 1.4571428571428564,
#  Not again, she whispered to herself.: 0.02857142857142857,
#  Telepathy, telekinesis, and the occasional reality hiccup were bad enough, but with sleep-deprived mood swings the odds of catastrophe rose sharply.: 0.4571428571428572,
#  Project Phoenix was mentioned in the files, always followed by emergency protocols in red ink.
#  : 1.2285714285714286,
#  Historical records show three power states: latent powers stayed hidden until some unknown trigger forced them out, active powers worked predictably like clockwork, and volatile powers refused any pattern at all, requiring strict containment.: 1.6571428571428566,
#  Lead-lined chambers, industrial foam, and total silence were common safety measures.: 0.3142857142857143,
#  The worst mistake was introducing water near an electrical mutant, and that rule was broken too many times.
#  : 1.657142857142857,
#  Reed once claimed that the lattice could hold at negative one hundred twenty degrees Celsius if the feedline remained untouched.: 0.28571428571428575,
#  Hank never believed him, saying any sentence that started with if and ended with should was an invitation for disaster.: 0.34285714285714286,
#  In practice, they both knew the truth — nothing ever held for long.
#  : 1.6571428571428573,
#  There were always hyphenated words scribbled in the margins of reports, mother-in-law jokes that made no sense, X-men written in block capitals, numbers like 3.14 and 1e6 hidden in the data, random email addresses like professor.x@academy.org, and links to half-broken archives.: 1.5428571428571423,
#  Ellipses marked sudden stops, parentheses spiraled into nested loops, and no one could tell where one thought ended and the next began.
#  : 1.4571428571428573,
#  The last surviving entry from the Mutant Archive ended with a warning.: 0.5714285714285715,
#  Stay alive.: 0.05714285714285714,
#  Stay hidden.: 0.11428571428571428,
#  Or stay together.: 0.02857142857142857,
#  The rest of the world will not care which choice you make.
#  : 1.2857142857142858,
#  In 1986, the island of Genosha claimed it had no mutants.: 0.4857142857142857,
#  Satellite scans proved otherwise.: 0.05714285714285714,
#  Thermal anomalies marked twenty-three underground chambers, each averaging four meters below surface.: 0.2857142857142857,
#  Reports found on an encrypted drive spoke of collars tagged MK-IV, restricting cortical spikes to under 0.7 millivolts.: 0.45714285714285724,
#  The logs never named the captives, only numbers: 402, 718, 719B.
#
#  Storm hated confined air.: 1.3714285714285712,
#  The metal corridors of the submersible pressed on her senses like a steel coffin.: 0.5428571428571428,
#  Pressure readings rose with each dive, and her weather instincts fought the silence.: 0.2857142857142857,
#  The Atlantic above was calm, yet her bones ached as if a storm loomed just out of sight.: 0.19999999999999998,
#  Scott told her it was in her head.: 0.05714285714285714,
#  She didn’t believe him.
#  : 1.0571428571428572,
#  In training simulations, probability curves rarely matched reality.: 0.28571428571428575,
#  A model might predict an 85% chance of target neutralization, yet a coin dropped in the wrong moment could throw the result to zero.: 0.5142857142857143,
#  Logan treated probabilities as polite lies — useful only until the fight started.: 0.6857142857142858,
#  His claws made better arguments than any statistical forecast.
#  : 1.1428571428571428,
#  They never figured out why the Westchester alarm tripped at exactly 02:13 every third Thursday.: 0.17142857142857143,
#  Maintenance replaced wiring, swapped the backup generator, even gutted the entire subpanel.: 0.2571428571428571,
#  The alarm kept ringing, always the same timestamp, always cutting off after 41 seconds.: 0.28571428571428575,
#  Xavier wrote in his log that some things are not for fixing.
#  : 1.1714285714285715,
#  Cerebro’s records showed language anomalies among young mutants.: 0.6,
#  One could speak twelve dialects after two hours of exposure, another could only communicate in palindromes.: 0.17142857142857143,
#  Written reports contained oddities like “madam I’m adam” repeated fifty-three times in a row, with no apparent meaning.: 1.1142857142857139,
#  Linguists left confused, telepaths left silent.
#  : 1.2,
#  In 1999, a blackout across Eastern Europe lasted seventeen minutes.: 0.19999999999999998,
#  Satellite logs noted no solar flare, no geomagnetic spike, no explainable cause.: 0.3142857142857143,
#  Files later surfaced referencing “Subject Theta-7,” a mutant able to bend electromagnetic fields with nothing more than concentration.: 1.1142857142857139,
#  Witness accounts conflicted — some claimed to see a boy in the rubble, others swore no one was there at all.: 0.6285714285714287,
#  Energy signatures burned into the data like scars, still unexplained two decades later.
#  : 1.6285714285714286,
#  Jubilee once described mutant life as “walking into every room carrying fireworks no one asked for.”: 1.2571428571428571,
#  Her files included timestamps, discharge levels, and even stress ratings before each flare.: 0.28571428571428575,
#  Yet the most important detail was never technical — it was that her sparks made children laugh in shelters where hope was short supply.: 0.6857142857142858,
#  Analysts flagged the entry as “non-essential,” but it stayed in the record anyway.
#  : 1.7428571428571429,
#  Warpath wrote long, unfiltered reports filled with metaphors instead of measurements.: 0.4,
#  He compared training halls to “caves echoing with steel,” and tactical drills to “storms waiting for permission to break.”: 1.3714285714285712,
#  His language baffled technicians but resonated with other mutants, who said they understood him more than any dry percentage or curve.: 0.6857142857142857,
#  Sometimes, his words revealed more truth than a hundred charts.
#  : 1.1714285714285715,
#  By 2005, geneticists tracked more than three hundred known mutations worldwide.: 0.2,
#  They mapped alleles, cross-referenced genomes, and still ended with a margin of error wider than comfort allowed.: 0.4285714285714286,
#  A note buried in the data read: Evolution is not an equation, it’s a tide.: 0.3142857142857143,
#  You can measure waves but never predict when the ocean will rise.
#  : 1.2285714285714286,
#  Magneto’s prison cell was technically a floating room, suspended by non-ferrous cables over a saltwater pit.: 0.4571428571428572,
#  Every bolt and weld was ceramic.: 0.08571428571428572,
#  Guards rotated every ninety minutes to avoid familiarity, each carrying no metal larger than a paperclip.: 0.4,
#  The design was flawless until someone smuggled in a simple belt buckle.
#  : 1.1714285714285715,
#  Some powers aged with their hosts.: 0.2571428571428572,
#  Pyro’s flames lost brightness after age fifty, while Colossus’s steel skin took longer to manifest each morning.: 0.3714285714285715,
#  Beast kept records of these declines, noting cellular efficiency drops in percentage points: 0.9, 1.3, 1.8.: 0.45714285714285724,
#  He called it entropy in slow motion.
#  : 1.1428571428571428,
#  Not all mutants fought.: 0.4,
#  Some built.: 0.02857142857142857,
#  Forge once designed a drone the size of a fingernail that could map a city block in thirty seconds.: 0.37142857142857144,
#  It flew once, mapped perfectly, then exploded in midair.: 0.17142857142857143,
#  The debris weighed less than a feather.: 0.08571428571428572,
#  No one could replicate it.
#  : 1.0285714285714285,
#  Records of mutant births show spikes after high-energy events: solar flares, nuclear tests, and the unexplained blackout of ’94.: 0.9142857142857145,
#  Analysts plotted them on a timeline and found fractal-like patterns, repeating across decades.: 0.5142857142857142,
#  The same gap lengths, the same sudden rises.: 0.14285714285714285,
#  A cycle hiding in plain sight.
#  : 1.1428571428571428,
#  The last known sighting of Mystique was not on any battlefield but at a small train station in rural France.: 0.2857142857142857,
#  CCTV caught her walking past the ticket booth, face unshifted, carrying a book with no title on the cover.: 0.5142857142857143,
#  She boarded the train, sat by the window, and vanished when it emerged from the next tunnel.
#  : 1.2571428571428571,
#  Mutants aren’t just powerful — they’re proof that humanity can grow beyond its limits.: 1.057142857142857,
#  They don’t rely on gadgets or alien bloodlines.: 0.17142857142857143,
#  Their abilities are part of who they are, stitched into their DNA, and that makes their heroism feel more personal.: 0.2857142857142857,
#  When a mutant saves a city, it’s not a mask or a machine doing the work.: 0.6285714285714287,
#  It’s them, body and soul.
#  : 1.0571428571428572,
#  People admire mutants because they were born carrying a weight most couldn’t handle.: 0.7714285714285715,
#  There’s no “before” for them — no moment where they were ordinary.: 0.9714285714285715,
#  They grew up different, learned to control dangerous gifts, and still chose to help a world that didn’t always help them.: 0.6571428571428573,
#  That resilience earns respect.
#  : 1.1142857142857143,
#  Everyday citizens can see themselves in mutants more easily than in other heroes.: 0.5142857142857143,
#  You can’t train to be from another planet or buy your way into super strength, but the idea that evolution could give anyone the potential to do great things is inspiring.: 0.5142857142857143,
#  Mutants make people believe that heroism is not just an accident — it can be destiny.
#  : 2.0857142857142854,
#  When a mutant steps in to stop a disaster, the crowd knows it’s more than just power on display.: 0.6571428571428573,
#  It’s living proof that humanity’s future might not be something to fear.: 0.4857142857142857,
#  It might be something to look forward to.
#  : 1.0857142857142856,
#  Mutants are born different.: 0.5142857142857143,
#  They don’t choose their powers, and they don’t wait for an accident or a cosmic event to awaken them.: 0.4000000000000001,
#  Their abilities manifest naturally, often in childhood, and that alone terrifies people.: 0.4,
#  A hero in armor is a man in a machine.: 0.17142857142857143,
#  A mutant is something else entirely — living proof that nature can rewrite the rules at will.
#  : 2.0285714285714285,
#  For most citizens, it’s easier to trust heroes whose powers have an explanation.: 0.4285714285714286,
#  A soldier in a suit, a scientist bitten by something strange, an alien from another planet — those stories have beginnings and boundaries.: 0.8285714285714286,
#  Mutants have neither.: 0.34285714285714286,
#  Their origins are tangled in biology, genetics, and whispers of evolution, which means anyone, anywhere, could be one without knowing it yet.: 0.2857142857142857,
#  That uncertainty breeds fear.
#  : 1.1714285714285715,
#  Fear turns into prejudice fast.: 0.2,
#  Newspapers talk about mutants as a “problem,” not as individuals.: 0.9428571428571428,
#  Politicians campaign on the promise of registration.: 0.08571428571428572,
#  Neighbors glance too long at a kid who runs faster than he should.: 0.2285714285714286,
#  When a mutant saves a city, the headlines still focus on the destruction caused during the rescue.: 0.6857142857142858,
#  If a non-mutant does the same, they get parades.
#  : 1.4571428571428573,
#  Superheroes are celebrated because they are seen as exceptional individuals — rare, special, chosen.: 0.6285714285714287,
#  Mutants are hated because they represent a future people can’t control.: 0.7714285714285716,
#  It’s not that the world doesn’t need them.: 0.2,
#  It’s that the world fears it might become them.
#  : 1.2,
#  Mutants sit in a strange place in the public mind.: 0.5428571428571429,
#  To some, they’re heroes — proof that evolution can push humanity forward.: 0.9142857142857145,
#  To others, they’re walking reminders that the world is changing in ways no one can control.: 0.4857142857142857,
#  Every time a mutant saves lives, the headlines split: one side celebrates, the other asks if their powers make them too dangerous to be trusted.
#  : 1.942857142857143,
#  The admiration is easy to understand.: 0.08571428571428572,
#  Many mutants spend their entire lives training to keep their abilities in check, choosing to risk themselves to protect strangers.: 0.8285714285714287,
#  They face the same threats as any other superhero, but often without the public’s full support.: 0.2,
#  That persistence is hard not to respect.
#  : 1.1142857142857143,
#  The fear comes from the unknown.: 0.19999999999999998,
#  A masked vigilante can hang up the suit.: 0.14285714285714285,
#  An alien can fly home.: 0.14285714285714285,
#  But mutants can’t stop being what they are, and no one can predict what abilities the next generation will have.: 0.6571428571428573,
#  For some, that’s exciting — a glimpse into the future of humankind.: 0.5714285714285715,
#  For others, it’s terrifying — a sign that humanity might become something unrecognizable.
#  : 1.6,
#  And so, mutants live in this constant push and pull between acceptance and suspicion.: 0.5714285714285715,
#  Loved in some cities, feared in others, and always aware that a single bad moment could tip the balance.
#  : 1.3142857142857143,
#  Mutants didn’t ask to be born different.: 0.5428571428571429,
#  But the world treats them like it’s a choice.: 0.5142857142857142,
#  A hero in a cape gets a parade.: 0.17142857142857143,
#  A mutant in the same fight gets a police escort… to a containment cell.
#  : 1.685714285714286,
#  People fear that power they can’t switch off, can’t hand over, can’t control.: 0.5142857142857143,
#  Every mutant is a walking question mark, and humans hate unanswered questions.
#  : 1.6285714285714286,
#  The irony?: 0.02857142857142857,
#  Most mutants want the same thing as everyone else — a life.: 0.8571428571428572,
#  Safety.: 0.02857142857142857,
#  But the second their genes reveal something extraordinary, that dream burns up in suspicion.
#  : 1.2285714285714286,
#  For every cheer, there’s a jeer.: 0.05714285714285714,
#  For every handshake, there’s a locked door.: 0.08571428571428572,
#  Mutants fight for the people, but the people can’t decide if they’re saviors or the first wave of something worse.: 0.8285714285714285}

# %%
from heapq import nlargest

# %%
# Lets say 40% of the summary

select_length = int(len(sentence_tokens)*0.4)
select_length
# Out:
# 60

# %%
summary = nlargest(select_length,sentence_scores, key = sentence_scores.get)
summary
# Out:
# [Mutants make people believe that heroism is not just an accident — it can be destiny.
#  ,
#  A mutant is something else entirely — living proof that nature can rewrite the rules at will.
#  ,
#  Every time a mutant saves lives, the headlines split: one side celebrates, the other asks if their powers make them too dangerous to be trusted.
#  ,
#  Analysts flagged the entry as “non-essential,” but it stayed in the record anyway.
#  ,
#  A mutant in the same fight gets a police escort… to a containment cell.
#  ,
#  In practice, they both knew the truth — nothing ever held for long.
#  ,
#  The worst mistake was introducing water near an electrical mutant, and that rule was broken too many times.
#  ,
#  Historical records show three power states: latent powers stayed hidden until some unknown trigger forced them out, active powers worked predictably like clockwork, and volatile powers refused any pattern at all, requiring strict containment.,
#  Energy signatures burned into the data like scars, still unexplained two decades later.
#  ,
#  Every mutant is a walking question mark, and humans hate unanswered questions.
#  ,
#  For others, it’s terrifying — a sign that humanity might become something unrecognizable.
#  ,
#  There were always hyphenated words scribbled in the margins of reports, mother-in-law jokes that made no sense, X-men written in block capitals, numbers like 3.14 and 1e6 hidden in the data, random email addresses like professor.x@academy.org, and links to half-broken archives.,
#  Ellipses marked sudden stops, parentheses spiraled into nested loops, and no one could tell where one thought ended and the next began.
#  ,
#  If a non-mutant does the same, they get parades.
#  ,
#  Sample IDs X-002, X23-A.
#
#  Jean Grey woke up with the taste of ozone and a headache that felt like someone had rearranged her skull.,
#  The logs never named the captives, only numbers: 402, 718, 719B.
#
#  Storm hated confined air.,
#  He compared training halls to “caves echoing with steel,” and tactical drills to “storms waiting for permission to break.”,
#  Loved in some cities, feared in others, and always aware that a single bad moment could tip the balance.
#  ,
#  The rest of the world will not care which choice you make.
#  ,
#  Jubilee once described mutant life as “walking into every room carrying fireworks no one asked for.”,
#  She boarded the train, sat by the window, and vanished when it emerged from the next tunnel.
#  ,
#  Project Phoenix was mentioned in the files, always followed by emergency protocols in red ink.
#  ,
#  You can measure waves but never predict when the ocean will rise.
#  ,
#  But the second their genes reveal something extraordinary, that dream burns up in suspicion.
#  ,
#  Linguists left confused, telepaths left silent.
#  ,
#  It’s that the world fears it might become them.
#  ,
#  Xavier wrote in his log that some things are not for fixing.
#  ,
#  Sometimes, his words revealed more truth than a hundred charts.
#  ,
#  The design was flawless until someone smuggled in a simple belt buckle.
#  ,
#  That uncertainty breeds fear.
#  ,
#  His claws made better arguments than any statistical forecast.
#  ,
#  He called it entropy in slow motion.
#  ,
#  A cycle hiding in plain sight.
#  ,
#  That resilience earns respect.
#  ,
#  That persistence is hard not to respect.
#  ,
#  Written reports contained oddities like “madam I’m adam” repeated fifty-three times in a row, with no apparent meaning.,
#  Files later surfaced referencing “Subject Theta-7,” a mutant able to bend electromagnetic fields with nothing more than concentration.,
#  It might be something to look forward to.
#  ,
#  She didn’t believe him.
#  ,
#  It’s them, body and soul.
#  ,
#  Mutants aren’t just powerful — they’re proof that humanity can grow beyond its limits.,
#  No one could replicate it.
#  ,
#  There’s no “before” for them — no moment where they were ordinary.,
#  Newspapers talk about mutants as a “problem,” not as individuals.,
#  Records of mutant births show spikes after high-energy events: solar flares, nuclear tests, and the unexplained blackout of ’94.,
#  To some, they’re heroes — proof that evolution can push humanity forward.,
#  Most mutants want the same thing as everyone else — a life.,
#  Many mutants spend their entire lives training to keep their abilities in check, choosing to risk themselves to protect strangers.,
#  A soldier in a suit, a scientist bitten by something strange, an alien from another planet — those stories have beginnings and boundaries.,
#  Mutants fight for the people, but the people can’t decide if they’re saviors or the first wave of something worse.,
#  Mutants are hated because they represent a future people can’t control.,
#  People admire mutants because they were born carrying a weight most couldn’t handle.,
#  Logan treated probabilities as polite lies — useful only until the fight started.,
#  Yet the most important detail was never technical — it was that her sparks made children laugh in shelters where hope was short supply.,
#  When a mutant saves a city, the headlines still focus on the destruction caused during the rescue.,
#  His language baffled technicians but resonated with other mutants, who said they understood him more than any dry percentage or curve.,
#  They grew up different, learned to control dangerous gifts, and still chose to help a world that didn’t always help them.,
#  When a mutant steps in to stop a disaster, the crowd knows it’s more than just power on display.,
#  But mutants can’t stop being what they are, and no one can predict what abilities the next generation will have.,
#  Witness accounts conflicted — some claimed to see a boy in the rubble, others swore no one was there at all.]

# %%
final_summary = [word.text for word in summary]
final_summary
# Out:
# ['Mutants make people believe that heroism is not just an accident — it can be destiny.\n\n',
#  'A mutant is something else entirely — living proof that nature can rewrite the rules at will.\n\n',
#  'Every time a mutant saves lives, the headlines split: one side celebrates, the other asks if their powers make them too dangerous to be trusted.\n\n',
#  'Analysts flagged the entry as “non-essential,” but it stayed in the record anyway.\n\n',
#  'A mutant in the same fight gets a police escort… to a containment cell.\n\n',
#  'In practice, they both knew the truth — nothing ever held for long.\n\n',
#  'The worst mistake was introducing water near an electrical mutant, and that rule was broken too many times.\n\n',
#  'Historical records show three power states: latent powers stayed hidden until some unknown trigger forced them out, active powers worked predictably like clockwork, and volatile powers refused any pattern at all, requiring strict containment.',
#  'Energy signatures burned into the data like scars, still unexplained two decades later.\n\n',
#  'Every mutant is a walking question mark, and humans hate unanswered questions.\n\n',
#  'For others, it’s terrifying — a sign that humanity might become something unrecognizable.\n\n',
#  'There were always hyphenated words scribbled in the margins of reports, mother-in-law jokes that made no sense, X-men written in block capitals, numbers like 3.14 and 1e6 hidden in the data, random email addresses like professor.x@academy.org, and links to half-broken archives.',
#  'Ellipses marked sudden stops, parentheses spiraled into nested loops, and no one could tell where one thought ended and the next began.\n\n',
#  'If a non-mutant does the same, they get parades.\n\n',
#  'Sample IDs X-002, X23-A.\n\nJean Grey woke up with the taste of ozone and a headache that felt like someone had rearranged her skull.',
#  'The logs never named the captives, only numbers: 402, 718, 719B.\n\nStorm hated confined air.',
#  'He compared training halls to “caves echoing with steel,” and tactical drills to “storms waiting for permission to break.”',
#  'Loved in some cities, feared in others, and always aware that a single bad moment could tip the balance.\n\n',
#  'The rest of the world will not care which choice you make.\n\n',
#  'Jubilee once described mutant life as “walking into every room carrying fireworks no one asked for.”',
#  'She boarded the train, sat by the window, and vanished when it emerged from the next tunnel.\n\n',
#  'Project Phoenix was mentioned in the files, always followed by emergency protocols in red ink.\n\n',
#  'You can measure waves but never predict when the ocean will rise.\n\n',
#  'But the second their genes reveal something extraordinary, that dream burns up in suspicion.\n\n',
#  'Linguists left confused, telepaths left silent.\n\n',
#  'It’s that the world fears it might become them.\n\n',
#  'Xavier wrote in his log that some things are not for fixing.\n\n',
#  'Sometimes, his words revealed more truth than a hundred charts.\n\n',
#  'The design was flawless until someone smuggled in a simple belt buckle.\n\n',
#  'That uncertainty breeds fear.\n\n',
#  'His claws made better arguments than any statistical forecast.\n\n',
#  'He called it entropy in slow motion.\n\n',
#  'A cycle hiding in plain sight.\n\n',
#  'That resilience earns respect.\n\n',
#  'That persistence is hard not to respect.\n\n',
#  'Written reports contained oddities like “madam I’m adam” repeated fifty-three times in a row, with no apparent meaning.',
#  'Files later surfaced referencing “Subject Theta-7,” a mutant able to bend electromagnetic fields with nothing more than concentration.',
#  'It might be something to look forward to.\n\n',
#  'She didn’t believe him.\n\n',
#  'It’s them, body and soul.\n\n',
#  'Mutants aren’t just powerful — they’re proof that humanity can grow beyond its limits.',
#  'No one could replicate it.\n\n',
#  'There’s no “before” for them — no moment where they were ordinary.',
#  'Newspapers talk about mutants as a “problem,” not as individuals.',
#  'Records of mutant births show spikes after high-energy events: solar flares, nuclear tests, and the unexplained blackout of ’94.',
#  'To some, they’re heroes — proof that evolution can push humanity forward.',
#  'Most mutants want the same thing as everyone else — a life.',
#  'Many mutants spend their entire lives training to keep their abilities in check, choosing to risk themselves to protect strangers.',
#  'A soldier in a suit, a scientist bitten by something strange, an alien from another planet — those stories have beginnings and boundaries.',
#  'Mutants fight for the people, but the people can’t decide if they’re saviors or the first wave of something worse.',
#  'Mutants are hated because they represent a future people can’t control.',
#  'People admire mutants because they were born carrying a weight most couldn’t handle.',
#  'Logan treated probabilities as polite lies — useful only until the fight started.',
#  'Yet the most important detail was never technical — it was that her sparks made children laugh in shelters where hope was short supply.',
#  'When a mutant saves a city, the headlines still focus on the destruction caused during the rescue.',
#  'His language baffled technicians but resonated with other mutants, who said they understood him more than any dry percentage or curve.',
#  'They grew up different, learned to control dangerous gifts, and still chose to help a world that didn’t always help them.',
#  'When a mutant steps in to stop a disaster, the crowd knows it’s more than just power on display.',
#  'But mutants can’t stop being what they are, and no one can predict what abilities the next generation will have.',
#  'Witness accounts conflicted — some claimed to see a boy in the rubble, others swore no one was there at all.']
